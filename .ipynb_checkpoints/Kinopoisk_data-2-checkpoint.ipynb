# %% [markdown]
# # Анализ фильмов с Кинопоиска
# __Подготовили:__ Стержанова Виталия, Купцова Александра и Мукимова Алина

# %% [markdown]
# ## Шаг 1: выбор темы

# %% [markdown]
# В качестве темы проекта мы выбрали анализ данных о фильмах с Кинопоиска.

# %% [markdown]
# ## Шаг 2: cбор данных

# %% [markdown]
# Для начала спарсим данные о 4000 фильмах с Кинопоиска.

# %%
import requests
import datetime
import json

headers = {"X-API-KEY": "DHV3YYD-S2Z4D9T-P0Y4VDD-YKB776Q"}


def get_movies_for_last_year():
    params = {
        'selectFields': 'name movieLength genres rating type votes year budget fees distributors premiere',
        'type': 'movie',
        'sortField': 'votes.kp',
        'sortType': '-1',
        'limit': 4000
    }
    response = requests.get(
        'https://api.kinopoisk.dev/v1.3/movie',
        headers=headers,
        params=params
    )

    return response.text


movies = get_movies_for_last_year()
movies = movies.replace('\xa0', ' ')

with open('data.txt', 'w', encoding='utf-8') as file:
    file.write(str(json.loads(movies)))
    file.flush()

formatted = json.loads(movies)
print(len(formatted['docs']))
# print(json.dumps(formatted, sort_keys=True, indent=4, ensure_ascii=True))
# Out:
# 4000

# %%
dict = formatted['docs']
dict
# Out:
# [{'fees': {'world': {'value': 426588510, 'currency': '$'},
#    'russia': {'value': 1725813, 'currency': '$'},
#    'usa': {'value': 10198820, 'currency': '$'}},
#   'rating': {'kp': 8.805,
#    'imdb': 8.5,
#    'filmCritics': 6.8,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 1582052,
#    'imdb': 882411,
#    'filmCritics': 130,
#    'russianFilmCritics': 12,
#    'await': 15},
#   'movieLength': 112,
#   'type': 'movie',
#   'name': '1+1',
#   'distributors': {'distributor': 'Каскад фильм',
#    'distributorRelease': 'Новый Диск'},
#   'premiere': {'world': '2011-09-23T00:00:00.000Z',
#    'russia': '2012-04-26T00:00:00.000Z'},
#   'year': 2011,
#   'budget': {'value': 9500000, 'currency': '€'},
#   'genres': [{'name': 'драма'}, {'name': 'комедия'}, {'name': 'биография'}]},
#  {'fees': {'world': {'value': 115171795, 'currency': '$'},
#    'russia': {'value': 18003343, 'currency': '$'},
#    'usa': {'value': 36471795, 'currency': '$'}},
#   'rating': {'kp': 8.548,
#    'imdb': 7.8,
#    'filmCritics': 6.5,
#    'russianFilmCritics': 86.3636,
#    'await': None},
#   'votes': {'kp': 1404260,
#    'imdb': 361184,
#    'filmCritics': 277,
#    'russianFilmCritics': 22,
#    'await': 13642},
#   'movieLength': 113,
#   'type': 'movie',
#   'name': 'Джентльмены',
#   'distributors': {'distributor': 'Вольга', 'distributorRelease': None},
#   'premiere': {'world': '2019-12-03T00:00:00.000Z',
#    'russia': '2020-02-13T00:00:00.000Z'},
#   'year': 2019,
#   'budget': {'value': 22000000, 'currency': '$'},
#   'genres': [{'name': 'криминал'}, {'name': 'комедия'}, {'name': 'боевик'}]},
#  {'fees': {'world': {'value': 392000694, 'currency': '$'},
#    'russia': {'value': 13796916, 'currency': '$'},
#    'usa': {'value': 116900694, 'currency': '$'}},
#   'rating': {'kp': 7.973,
#    'imdb': 8.2,
#    'filmCritics': 7.8,
#    'russianFilmCritics': 77.4194,
#    'await': None},
#   'votes': {'kp': 1116549,
#    'imdb': 1465395,
#    'filmCritics': 289,
#    'russianFilmCritics': 31,
#    'await': 43024},
#   'movieLength': 180,
#   'type': 'movie',
#   'name': 'Волк с Уолл-стрит',
#   'distributors': {'distributor': 'West', 'distributorRelease': 'West Video'},
#   'premiere': {'world': '2013-12-09T00:00:00.000Z',
#    'russia': '2014-02-06T00:00:00.000Z'},
#   'year': 2013,
#   'budget': {'value': 100000000, 'currency': '$'},
#   'genres': [{'name': 'драма'},
#    {'name': 'криминал'},
#    {'name': 'биография'},
#    {'name': 'комедия'}]},
#  {'rating': {'kp': 7.59,
#    'imdb': 7.1,
#    'filmCritics': 6.3,
#    'russianFilmCritics': 72.973,
#    'await': None},
#   'votes': {'kp': 1085059,
#    'imdb': 190690,
#    'filmCritics': 256,
#    'russianFilmCritics': 37,
#    'await': 23492},
#   'movieLength': 119,
#   'type': 'movie',
#   'name': 'Гнев человеческий',
#   'distributors': {'distributor': 'Вольга', 'distributorRelease': None},
#   'premiere': {'world': '2021-04-22T00:00:00.000Z',
#    'russia': '2021-04-22T00:00:00.000Z'},
#   'year': 2021,
#   'genres': [{'name': 'боевик'}, {'name': 'триллер'}],
#   'budget': {'value': 40000000, 'currency': '$'},
#   'fees': {'world': {'value': 103966489, 'currency': '$'},
#    'russia': {'value': 13318455, 'currency': '$'},
#    'usa': {'value': 27466489, 'currency': '$'}}},
#  {'type': 'movie',
#   'name': 'Брат',
#   'rating': {'kp': 8.294,
#    'imdb': 7.8,
#    'filmCritics': 7.6,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 1058255,
#    'imdb': 22847,
#    'filmCritics': 5,
#    'russianFilmCritics': 2,
#    'await': 0},
#   'distributors': {'distributor': 'Кармен-Премьер, СТВ',
#    'distributorRelease': 'Союз-Видео'},
#   'premiere': {'world': '1997-05-17T00:00:00.000Z',
#    'russia': '1997-12-12T00:00:00.000Z'},
#   'year': 1997,
#   'genres': [{'name': 'драма'}, {'name': 'криминал'}, {'name': 'боевик'}],
#   'budget': {},
#   'movieLength': 100,
#   'fees': {'world': {'value': 1362281, 'currency': '$'}}},
#  {'fees': {'world': {'value': 476684675, 'currency': '$'},
#    'usa': {'value': 285761243, 'currency': '$'}},
#   'rating': {'kp': 8.275,
#    'imdb': 7.7,
#    'filmCritics': 5.8,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 1010104,
#    'imdb': 604782,
#    'filmCritics': 62,
#    'russianFilmCritics': 0,
#    'await': 0},
#   'movieLength': 103,
#   'type': 'movie',
#   'name': 'Один дома',
#   'distributors': {'distributor': None, 'distributorRelease': 'Гемини-Фильм'},
#   'premiere': {'world': '1990-11-10T00:00:00.000Z'},
#   'year': 1990,
#   'budget': {'value': 18000000, 'currency': '$'},
#   'genres': [{'name': 'комедия'}, {'name': 'семейный'}]},
#  {'fees': {'world': {'value': 2923905528, 'currency': '$'},
#    'russia': {'value': 119903638, 'currency': '$'},
#    'usa': {'value': 785221649, 'currency': '$'}},
#   'rating': {'kp': 7.971,
#    'imdb': 7.9,
#    'filmCritics': 7.4,
#    'russianFilmCritics': 75,
#    'await': None},
#   'votes': {'kp': 980562,
#    'imdb': 1342918,
#    'filmCritics': 335,
#    'russianFilmCritics': 12,
#    'await': 38689},
#   'movieLength': 162,
#   'type': 'movie',
#   'name': 'Аватар',
#   'distributors': {'distributor': 'Двадцатый Век Фокс СНГ',
#    'distributorRelease': 'Двадцатый Век Фокс СНГ'},
#   'premiere': {'world': '2009-12-10T00:00:00.000Z',
#    'russia': '2009-12-17T00:00:00.000Z'},
#   'year': 2009,
#   'budget': {'value': 237000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'драма'},
#    {'name': 'приключения'}]},
#  {'fees': {'world': {'value': 28418687, 'currency': '$'},
#    'russia': {'value': 87432, 'currency': '$'},
#    'usa': {'value': 28341469, 'currency': '$'}},
#   'rating': {'kp': 9.108,
#    'imdb': 9.3,
#    'filmCritics': 8.4,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 927966,
#    'imdb': 2748933,
#    'filmCritics': 82,
#    'russianFilmCritics': 1,
#    'await': 2},
#   'movieLength': 142,
#   'type': 'movie',
#   'name': 'Побег из Шоушенка',
#   'distributors': {'distributor': 'Иноекино',
#    'distributorRelease': 'Videogram, Союз-Видео'},
#   'premiere': {'world': '1994-09-10T00:00:00.000Z',
#    'russia': '2019-10-24T00:00:00.000Z'},
#   'year': 1994,
#   'budget': {'value': 25000000, 'currency': '$'},
#   'genres': [{'name': 'драма'}]},
#  {'fees': {'world': {'value': 828322032, 'currency': '$'},
#    'russia': {'value': 66113, 'currency': '$'},
#    'usa': {'value': 292576195, 'currency': '$'}},
#   'rating': {'kp': 8.663,
#    'imdb': 8.8,
#    'filmCritics': 8.1,
#    'russianFilmCritics': 80.9524,
#    'await': None},
#   'votes': {'kp': 922166,
#    'imdb': 2415500,
#    'filmCritics': 367,
#    'russianFilmCritics': 21,
#    'await': 42545},
#   'movieLength': 148,
#   'type': 'movie',
#   'name': 'Начало',
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2010-07-08T00:00:00.000Z',
#    'russia': '2010-07-22T00:00:00.000Z'},
#   'year': 2010,
#   'budget': {'value': 160000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'триллер'},
#    {'name': 'драма'},
#    {'name': 'детектив'}]},
#  {'fees': {'world': {'value': 286801374, 'currency': '$'},
#    'usa': {'value': 136801374, 'currency': '$'}},
#   'rating': {'kp': 9.073,
#    'imdb': 8.6,
#    'filmCritics': 6.8,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 898929,
#    'imdb': 1336492,
#    'filmCritics': 136,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'movieLength': 189,
#   'type': 'movie',
#   'name': 'Зеленая миля',
#   'distributors': {'distributor': 'West', 'distributorRelease': 'West Video'},
#   'premiere': {'world': '1999-12-06T00:00:00.000Z',
#    'russia': '2000-04-18T00:00:00.000Z'},
#   'year': 1999,
#   'budget': {'value': 60000000, 'currency': '$'},
#   'genres': [{'name': 'драма'}, {'name': 'фэнтези'}, {'name': 'криминал'}]},
#  {'type': 'movie',
#   'name': 'Иван Васильевич меняет профессию',
#   'rating': {'kp': 8.785,
#    'imdb': 8.2,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 894639,
#    'imdb': 17473,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': 0},
#   'distributors': {'distributor': None,
#    'distributorRelease': 'Парадиз, Lizard Cinema Trade'},
#   'premiere': {'world': '1973-09-17T00:00:00.000Z'},
#   'year': 1973,
#   'genres': [{'name': 'комедия'},
#    {'name': 'фантастика'},
#    {'name': 'приключения'}],
#   'budget': {},
#   'movieLength': 88,
#   'fees': {'world': {}, 'russia': {}, 'usa': {}}},
#  {'fees': {'world': {'value': 312897920, 'currency': '$'},
#    'russia': {'value': 6288706, 'currency': '$'},
#    'usa': {'value': 165363234, 'currency': '$'}},
#   'rating': {'kp': 8.087,
#    'imdb': 7.9,
#    'filmCritics': 8.3,
#    'russianFilmCritics': 90,
#    'await': None},
#   'votes': {'kp': 888693,
#    'imdb': 728146,
#    'filmCritics': 474,
#    'russianFilmCritics': 20,
#    'await': 9141},
#   'movieLength': 130,
#   'type': 'movie',
#   'name': 'Достать ножи',
#   'distributors': {'distributor': 'Централ Партнершип',
#    'distributorRelease': None},
#   'premiere': {'world': '2019-09-07T00:00:00.000Z',
#    'russia': '2019-11-28T00:00:00.000Z'},
#   'year': 2019,
#   'budget': {'value': 40000000, 'currency': '$'},
#   'genres': [{'name': 'детектив'},
#    {'name': 'комедия'},
#    {'name': 'драма'},
#    {'name': 'криминал'}]},
#  {'fees': {'world': {'value': 974755371, 'currency': '$'},
#    'russia': {'value': 5474384, 'currency': '$'},
#    'usa': {'value': 317575550, 'currency': '$'}},
#   'rating': {'kp': 8.263,
#    'imdb': 7.6,
#    'filmCritics': 7.1,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 882297,
#    'imdb': 810421,
#    'filmCritics': 200,
#    'russianFilmCritics': 2,
#    'await': 0},
#   'movieLength': 152,
#   'type': 'movie',
#   'name': 'Гарри Поттер и философский камень',
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'Мост-Видео, Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2001-11-04T00:00:00.000Z',
#    'russia': '2002-03-21T00:00:00.000Z'},
#   'year': 2001,
#   'budget': {'value': 125000000, 'currency': '$'},
#   'genres': [{'name': 'фэнтези'},
#    {'name': 'приключения'},
#    {'name': 'семейный'}]},
#  {'rating': {'kp': 8.373,
#    'imdb': 8.1,
#    'filmCritics': 7.1,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 882257,
#    'imdb': 1154626,
#    'filmCritics': 220,
#    'russianFilmCritics': 2,
#    'await': 0},
#   'movieLength': 143,
#   'type': 'movie',
#   'name': 'Пираты Карибского моря: Проклятие Черной жемчужины',
#   'distributors': {'distributor': 'Каскад фильм',
#    'distributorRelease': 'Уолт Дисней Компани СНГ'},
#   'premiere': {'world': '2003-06-28T00:00:00.000Z',
#    'russia': '2003-08-20T00:00:00.000Z'},
#   'year': 2003,
#   'budget': {'value': 140000000, 'currency': '$'},
#   'genres': [{'name': 'фэнтези'}, {'name': 'боевик'}, {'name': 'приключения'}],
#   'fees': {'world': {'value': 654264015, 'currency': '$'},
#    'russia': {'value': 9060000, 'currency': '$'},
#    'usa': {'value': 305413918, 'currency': '$'}}},
#  {'fees': {'world': {'value': 774136705, 'currency': '$'},
#    'russia': {'value': 26192066, 'currency': '$'},
#    'usa': {'value': 188020017, 'currency': '$'}},
#   'rating': {'kp': 8.621,
#    'imdb': 8.7,
#    'filmCritics': 7.1,
#    'russianFilmCritics': 80.6452,
#    'await': None},
#   'votes': {'kp': 875082,
#    'imdb': 1913634,
#    'filmCritics': 375,
#    'russianFilmCritics': 31,
#    'await': 78051},
#   'movieLength': 169,
#   'type': 'movie',
#   'name': 'Интерстеллар',
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'CP Дистрибуция'},
#   'premiere': {'world': '2014-10-26T00:00:00.000Z',
#    'russia': '2014-11-06T00:00:00.000Z'},
#   'year': 2014,
#   'budget': {'value': 165000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'драма'},
#    {'name': 'приключения'}]},
#  {'fees': {'world': {'value': 543825, 'currency': '$'},
#    'russia': {'value': 1080000, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Брат 2',
#   'rating': {'kp': 8.181,
#    'imdb': 7.7,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 849404,
#    'imdb': 16207,
#    'filmCritics': 0,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'distributors': {'distributor': 'Интерсинема-Арт, СТВ',
#    'distributorRelease': 'Союз-Видео'},
#   'premiere': {'world': '2000-08-30T00:00:00.000Z',
#    'russia': '2000-05-11T00:00:00.000Z'},
#   'year': 2000,
#   'budget': {'value': 1500000, 'currency': '$'},
#   'genres': [{'name': 'боевик'}, {'name': 'криминал'}],
#   'movieLength': 127},
#  {'fees': {'world': {'value': 100853753, 'currency': '$'},
#    'russia': {'value': 334590, 'currency': '$'},
#    'usa': {'value': 37030102, 'currency': '$'}},
#   'rating': {'kp': 8.658,
#    'imdb': 8.8,
#    'filmCritics': 7.4,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 848157,
#    'imdb': 2188713,
#    'filmCritics': 181,
#    'russianFilmCritics': 2,
#    'await': 0},
#   'movieLength': 139,
#   'type': 'movie',
#   'name': 'Бойцовский клуб',
#   'distributors': {'distributor': 'Гемини, Иноекино',
#    'distributorRelease': 'Двадцатый Век Фокс СНГ'},
#   'premiere': {'world': '1999-09-10T00:00:00.000Z',
#    'russia': '2000-01-13T00:00:00.000Z'},
#   'year': 1999,
#   'budget': {'value': 63000000, 'currency': '$'},
#   'genres': [{'name': 'триллер'}, {'name': 'драма'}, {'name': 'криминал'}]},
#  {'fees': {'world': {'value': 677387716, 'currency': '$'},
#    'russia': {'value': 84460, 'currency': '$'},
#    'usa': {'value': 329694499, 'currency': '$'}},
#   'rating': {'kp': 8.918,
#    'imdb': 8.8,
#    'filmCritics': 7.5,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 826539,
#    'imdb': 2138316,
#    'filmCritics': 107,
#    'russianFilmCritics': 1,
#    'await': 6},
#   'movieLength': 142,
#   'type': 'movie',
#   'name': 'Форрест Гамп',
#   'distributors': {'distributor': 'Иноекино',
#    'distributorRelease': 'Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '1994-06-23T00:00:00.000Z',
#    'russia': '2020-02-13T00:00:00.000Z'},
#   'year': 1994,
#   'budget': {'value': 55000000, 'currency': '$'},
#   'genres': [{'name': 'драма'},
#    {'name': 'комедия'},
#    {'name': 'мелодрама'},
#    {'name': 'история'},
#    {'name': 'военный'}]},
#  {'fees': {'world': {'value': 321752656, 'currency': '$'},
#    'russia': {'value': 9319859, 'currency': '$'},
#    'usa': {'value': 85080171, 'currency': '$'}},
#   'rating': {'kp': 8.407,
#    'imdb': 8.2,
#    'filmCritics': 7.2,
#    'russianFilmCritics': 93.75,
#    'await': None},
#   'votes': {'kp': 821099,
#    'imdb': 520042,
#    'filmCritics': 364,
#    'russianFilmCritics': 16,
#    'await': 6866},
#   'movieLength': 130,
#   'type': 'movie',
#   'name': 'Зеленая книга',
#   'distributors': {'distributor': 'Capella Film', 'distributorRelease': None},
#   'premiere': {'world': '2018-09-11T00:00:00.000Z',
#    'russia': '2019-01-24T00:00:00.000Z'},
#   'year': 2018,
#   'budget': {'value': 23000000, 'currency': '$'},
#   'genres': [{'name': 'биография'}, {'name': 'комедия'}, {'name': 'драма'}]},
#  {'rating': {'kp': 8.705,
#    'imdb': 8.5,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 821024,
#    'imdb': 14036,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': 0},
#   'movieLength': 95,
#   'type': 'movie',
#   'name': 'Операция «Ы» и другие приключения Шурика',
#   'distributors': {'distributor': None,
#    'distributorRelease': 'Парадиз, Lizard Cinema Trade'},
#   'premiere': {'world': '1965-07-23T00:00:00.000Z'},
#   'year': 1965,
#   'genres': [{'name': 'комедия'}, {'name': 'мелодрама'}, {'name': 'криминал'}],
#   'fees': {'world': {}, 'russia': {}, 'usa': {}},
#   'budget': {}},
#  {'fees': {'world': {'value': 294804195, 'currency': '$'},
#    'russia': {'value': 5430049, 'currency': '$'},
#    'usa': {'value': 128012934, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Остров проклятых',
#   'rating': {'kp': 8.514,
#    'imdb': 8.2,
#    'filmCritics': 6.7,
#    'russianFilmCritics': 85.7143,
#    'await': None},
#   'votes': {'kp': 811736,
#    'imdb': 1362639,
#    'filmCritics': 263,
#    'russianFilmCritics': 7,
#    'await': 22948},
#   'distributors': {'distributor': 'Capella Film, Каскад фильм',
#    'distributorRelease': 'Союз-Видео'},
#   'premiere': {'world': '2010-02-13T00:00:00.000Z',
#    'russia': '2010-02-18T00:00:00.000Z'},
#   'year': 2009,
#   'budget': {'value': 80000000, 'currency': '$'},
#   'genres': [{'name': 'триллер'}, {'name': 'детектив'}, {'name': 'драма'}],
#   'movieLength': 138},
#  {'type': 'movie',
#   'name': 'Любовь и голуби',
#   'rating': {'kp': 8.288,
#    'imdb': 7.9,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 811345,
#    'imdb': 5215,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': 0},
#   'distributors': {'distributor': None, 'distributorRelease': 'Парадиз'},
#   'premiere': {'world': '1985-01-07T00:00:00.000Z'},
#   'year': 1984,
#   'genres': [{'name': 'мелодрама'}, {'name': 'комедия'}],
#   'budget': {},
#   'fees': {'world': {}, 'russia': {}, 'usa': {}},
#   'movieLength': 107},
#  {'fees': {'world': {'value': 2048359754, 'currency': '$'},
#    'russia': {'value': 34793936, 'currency': '$'},
#    'usa': {'value': 678815482, 'currency': '$'}},
#   'rating': {'kp': 8.064,
#    'imdb': 8.4,
#    'filmCritics': 7.6,
#    'russianFilmCritics': 86.3636,
#    'await': None},
#   'votes': {'kp': 787927,
#    'imdb': 1125357,
#    'filmCritics': 491,
#    'russianFilmCritics': 22,
#    'await': 77951},
#   'movieLength': 149,
#   'type': 'movie',
#   'name': 'Мстители: Война бесконечности',
#   'distributors': {'distributor': 'WDSSPR', 'distributorRelease': None},
#   'premiere': {'world': '2018-04-23T00:00:00.000Z',
#    'russia': '2018-05-03T00:00:00.000Z'},
#   'year': 2018,
#   'budget': {'value': 321000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'приключения'}]},
#  {'rating': {'kp': 6.907,
#    'imdb': 6.6,
#    'filmCritics': 4.5,
#    'russianFilmCritics': 38.8889,
#    'await': None},
#   'votes': {'kp': 783331,
#    'imdb': 506292,
#    'filmCritics': 364,
#    'russianFilmCritics': 18,
#    'await': 59982},
#   'movieLength': 112,
#   'type': 'movie',
#   'name': 'Веном',
#   'distributors': {'distributor': 'WDSSPR', 'distributorRelease': None},
#   'premiere': {'world': '2018-10-01T00:00:00.000Z',
#    'russia': '2018-10-04T00:00:00.000Z'},
#   'year': 2018,
#   'budget': {'value': 100000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'триллер'},
#    {'name': 'ужасы'}],
#   'fees': {'world': {'value': 856085151, 'currency': '$'},
#    'russia': {'value': 32747628, 'currency': '$'},
#    'usa': {'value': 213515506, 'currency': '$'}}},
#  {'fees': {'world': {'value': 2264743305, 'currency': '$'},
#    'russia': {'value': 18400000, 'currency': '$'},
#    'usa': {'value': 674292608, 'currency': '$'}},
#   'rating': {'kp': 8.384,
#    'imdb': 7.9,
#    'filmCritics': 8,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 778977,
#    'imdb': 1220119,
#    'filmCritics': 251,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'movieLength': 194,
#   'type': 'movie',
#   'name': 'Титаник',
#   'distributors': {'distributor': 'Гемини, Двадцатый Век Фокс СНГ',
#    'distributorRelease': 'Гемини-Фильм, Двадцатый Век Фокс СНГ'},
#   'premiere': {'world': '1997-11-01T00:00:00.000Z',
#    'russia': '1998-02-20T00:00:00.000Z'},
#   'year': 1997,
#   'budget': {'value': 200000000, 'currency': '$'},
#   'genres': [{'name': 'мелодрама'},
#    {'name': 'история'},
#    {'name': 'триллер'},
#    {'name': 'драма'}]},
#  {'fees': {'world': {'value': 2799439100, 'currency': '$'},
#    'russia': {'value': 47450130, 'currency': '$'},
#    'usa': {'value': 858373000, 'currency': '$'}},
#   'rating': {'kp': 7.848,
#    'imdb': 8.4,
#    'filmCritics': 8.2,
#    'russianFilmCritics': 70.5882,
#    'await': None},
#   'votes': {'kp': 743434,
#    'imdb': 1182124,
#    'filmCritics': 555,
#    'russianFilmCritics': 17,
#    'await': 96313},
#   'movieLength': 181,
#   'type': 'movie',
#   'name': 'Мстители: Финал',
#   'distributors': {'distributor': 'WDSSPR', 'distributorRelease': None},
#   'premiere': {'world': '2019-04-22T00:00:00.000Z',
#    'russia': '2019-04-29T00:00:00.000Z'},
#   'year': 2019,
#   'budget': {'value': 356000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'драма'},
#    {'name': 'приключения'}]},
#  {'fees': {'world': {'value': 213928762, 'currency': '$'},
#    'russia': {'value': 83843, 'currency': '$'},
#    'usa': {'value': 107928762, 'currency': '$'}},
#   'rating': {'kp': 8.645,
#    'imdb': 8.9,
#    'filmCritics': 9.2,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 714640,
#    'imdb': 2112034,
#    'filmCritics': 115,
#    'russianFilmCritics': 7,
#    'await': 1},
#   'movieLength': 154,
#   'type': 'movie',
#   'name': 'Криминальное чтиво',
#   'distributors': {'distributor': 'Каравелла DDC, Аргус-СВ',
#    'distributorRelease': 'West Video, Кармен Видео'},
#   'premiere': {'world': '1994-05-21T00:00:00.000Z',
#    'russia': '1995-09-29T00:00:00.000Z'},
#   'year': 1994,
#   'budget': {'value': 8000000, 'currency': '$'},
#   'genres': [{'name': 'криминал'}, {'name': 'драма'}]},
#  {'fees': {'world': {'value': 772776600, 'currency': '$'},
#    'russia': {'value': 37881775, 'currency': '$'},
#    'usa': {'value': 333176600, 'currency': '$'}},
#   'rating': {'kp': 7.845,
#    'imdb': 8,
#    'filmCritics': 7.8,
#    'russianFilmCritics': 83.3333,
#    'await': None},
#   'votes': {'kp': 701363,
#    'imdb': 1220887,
#    'filmCritics': 338,
#    'russianFilmCritics': 18,
#    'await': 46215},
#   'movieLength': 121,
#   'type': 'movie',
#   'name': 'Стражи Галактики',
#   'distributors': {'distributor': 'WDSSPR',
#    'distributorRelease': 'Уолт Дисней Компани СНГ'},
#   'premiere': {'world': '2014-07-21T00:00:00.000Z',
#    'russia': '2014-07-31T00:00:00.000Z'},
#   'year': 2014,
#   'budget': {'value': 170000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'приключения'},
#    {'name': 'комедия'}]},
#  {'rating': {'kp': 7.672,
#    'imdb': 8,
#    'filmCritics': 7.6,
#    'russianFilmCritics': 72,
#    'await': None},
#   'votes': {'kp': 693716,
#    'imdb': 680247,
#    'filmCritics': 498,
#    'russianFilmCritics': 25,
#    'await': 89730},
#   'movieLength': 155,
#   'type': 'movie',
#   'name': 'Дюна',
#   'distributors': {'distributor': 'UPI', 'distributorRelease': None},
#   'premiere': {'world': '2021-09-03T00:00:00.000Z',
#    'russia': '2021-09-16T00:00:00.000Z'},
#   'year': 2021,
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'драма'},
#    {'name': 'приключения'}],
#   'budget': {'value': 165000000, 'currency': '$'},
#   'fees': {'world': {'value': 402027830, 'currency': '$'},
#    'russia': {'value': 21931316, 'currency': '$'},
#    'usa': {'value': 108327830, 'currency': '$'}}},
#  {'fees': {'world': {'value': 161849455, 'currency': '$'},
#    'russia': {'value': 6199604, 'currency': '$'},
#    'usa': {'value': 79249455, 'currency': '$'}},
#   'rating': {'kp': 7.99,
#    'imdb': 7.4,
#    'filmCritics': 6.4,
#    'russianFilmCritics': 75,
#    'await': None},
#   'votes': {'kp': 693054,
#    'imdb': 589636,
#    'filmCritics': 202,
#    'russianFilmCritics': 8,
#    'await': 19262},
#   'movieLength': 105,
#   'type': 'movie',
#   'name': 'Области тьмы',
#   'distributors': {'distributor': 'Парадиз, Наше Кино',
#    'distributorRelease': 'CP-Digital'},
#   'premiere': {'world': '2011-03-08T00:00:00.000Z',
#    'russia': '2011-03-17T00:00:00.000Z'},
#   'year': 2011,
#   'budget': {'value': 26000000, 'currency': '$'},
#   'genres': [{'name': 'триллер'}, {'name': 'драма'}, {'name': 'фантастика'}]},
#  {'fees': {'world': {'value': 677718395, 'currency': '$'},
#    'russia': {'value': 25178707, 'currency': '$'},
#    'usa': {'value': 232641920, 'currency': '$'}},
#   'rating': {'kp': 7.517,
#    'imdb': 7.5,
#    'filmCritics': 7.3,
#    'russianFilmCritics': 94.7368,
#    'await': None},
#   'votes': {'kp': 691973,
#    'imdb': 766652,
#    'filmCritics': 388,
#    'russianFilmCritics': 19,
#    'await': 69981},
#   'movieLength': 115,
#   'type': 'movie',
#   'name': 'Доктор Стрэндж',
#   'distributors': {'distributor': 'WDSSPR', 'distributorRelease': None},
#   'premiere': {'world': '2016-10-13T00:00:00.000Z',
#    'russia': '2016-10-31T00:00:00.000Z'},
#   'year': 2016,
#   'budget': {'value': 165000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'фэнтези'},
#    {'name': 'боевик'},
#    {'name': 'приключения'}]},
#  {'fees': {'world': {'value': 42972994, 'currency': '$'},
#    'russia': {'value': 2339330, 'currency': '$'},
#    'usa': {'value': 1872994, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Легенда',
#   'rating': {'kp': 7.191,
#    'imdb': 6.9,
#    'filmCritics': 5.9,
#    'russianFilmCritics': 76.9231,
#    'await': None},
#   'votes': {'kp': 685837,
#    'imdb': 190969,
#    'filmCritics': 171,
#    'russianFilmCritics': 13,
#    'await': 16065},
#   'distributors': {'distributor': 'Парадиз', 'distributorRelease': 'Парадиз'},
#   'premiere': {'world': '2015-09-09T00:00:00.000Z',
#    'russia': '2015-10-01T00:00:00.000Z'},
#   'year': 2015,
#   'budget': {'value': 30000000, 'currency': '$'},
#   'genres': [{'name': 'криминал'}, {'name': 'триллер'}, {'name': 'драма'}],
#   'movieLength': 131},
#  {'fees': {'world': {'value': 463517383, 'currency': '$'},
#    'usa': {'value': 171479930, 'currency': '$'}},
#   'rating': {'kp': 8.497,
#    'imdb': 8.7,
#    'filmCritics': 7.8,
#    'russianFilmCritics': 60,
#    'await': None},
#   'votes': {'kp': 684499,
#    'imdb': 1959753,
#    'filmCritics': 162,
#    'russianFilmCritics': 5,
#    'await': 0},
#   'movieLength': 136,
#   'type': 'movie',
#   'name': 'Матрица',
#   'distributors': {'distributor': 'Каро-Премьер, Маурис Филм',
#    'distributorRelease': 'Мост-Видео, Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '1999-03-24T00:00:00.000Z',
#    'russia': '1999-10-14T00:00:00.000Z'},
#   'year': 1999,
#   'budget': {'value': 63000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'}, {'name': 'боевик'}]},
#  {'fees': {'world': {'value': 352114312, 'currency': '$'},
#    'russia': {'value': 2427426, 'currency': '$'},
#    'usa': {'value': 164615351, 'currency': '$'}},
#   'rating': {'kp': 8.527,
#    'imdb': 8.1,
#    'filmCritics': 7.9,
#    'russianFilmCritics': 80,
#    'await': None},
#   'votes': {'kp': 678554,
#    'imdb': 1022655,
#    'filmCritics': 203,
#    'russianFilmCritics': 5,
#    'await': 0},
#   'movieLength': 141,
#   'type': 'movie',
#   'name': 'Поймай меня, если сможешь',
#   'distributors': {'distributor': 'Ист-Вест',
#    'distributorRelease': 'Premier Digital'},
#   'premiere': {'world': '2002-12-16T00:00:00.000Z',
#    'russia': '2003-02-13T00:00:00.000Z'},
#   'year': 2002,
#   'budget': {'value': 52000000, 'currency': '$'},
#   'genres': [{'name': 'криминал'},
#    {'name': 'биография'},
#    {'name': 'комедия'}]},
#  {'fees': {'world': {'value': 1003045358, 'currency': '$'},
#    'russia': {'value': 8589100, 'currency': '$'},
#    'usa': {'value': 533345358, 'currency': '$'}},
#   'rating': {'kp': 8.52,
#    'imdb': 9,
#    'filmCritics': 8.6,
#    'russianFilmCritics': 45.4545,
#    'await': None},
#   'votes': {'kp': 678535,
#    'imdb': 2721301,
#    'filmCritics': 345,
#    'russianFilmCritics': 11,
#    'await': 1},
#   'movieLength': 152,
#   'type': 'movie',
#   'name': 'Темный рыцарь',
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2008-07-14T00:00:00.000Z',
#    'russia': '2008-08-14T00:00:00.000Z'},
#   'year': 2008,
#   'budget': {'value': 185000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'триллер'},
#    {'name': 'криминал'},
#    {'name': 'драма'}]},
#  {'fees': {'world': {'value': 1518812988, 'currency': '$'},
#    'russia': {'value': 43412056, 'currency': '$'},
#    'usa': {'value': 623357910, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Мстители',
#   'rating': {'kp': 7.893,
#    'imdb': 8,
#    'filmCritics': 8.1,
#    'russianFilmCritics': 83.3333,
#    'await': None},
#   'votes': {'kp': 673393,
#    'imdb': 1417056,
#    'filmCritics': 367,
#    'russianFilmCritics': 18,
#    'await': 54435},
#   'distributors': {'distributor': 'WDSSPR',
#    'distributorRelease': 'Уолт Дисней Компани СНГ'},
#   'premiere': {'world': '2012-04-11T00:00:00.000Z',
#    'russia': '2012-05-03T00:00:00.000Z'},
#   'year': 2012,
#   'budget': {'value': 220000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'фэнтези'},
#    {'name': 'приключения'}],
#   'movieLength': 137},
#  {'fees': {'world': {'value': 10560943, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Джентльмены удачи',
#   'rating': {'kp': 8.543,
#    'imdb': 8.4,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 670992,
#    'imdb': 12200,
#    'filmCritics': 0,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'distributors': {'distributor': None, 'distributorRelease': 'Парадиз'},
#   'premiere': {'world': '1971-12-13T00:00:00.000Z'},
#   'year': 1971,
#   'genres': [{'name': 'комедия'},
#    {'name': 'драма'},
#    {'name': 'криминал'},
#    {'name': 'детектив'}],
#   'budget': {},
#   'movieLength': 84},
#  {'rating': {'kp': 8.233,
#    'imdb': 8.4,
#    'filmCritics': 8,
#    'russianFilmCritics': 88.2353,
#    'await': None},
#   'votes': {'kp': 659702,
#    'imdb': 1601116,
#    'filmCritics': 298,
#    'russianFilmCritics': 34,
#    'await': 37999},
#   'movieLength': 165,
#   'type': 'movie',
#   'name': 'Джанго освобожденный',
#   'distributors': {'distributor': 'WDSSPR',
#    'distributorRelease': 'Columbia/Sony'},
#   'premiere': {'world': '2012-12-11T00:00:00.000Z',
#    'russia': '2013-01-17T00:00:00.000Z'},
#   'year': 2012,
#   'budget': {'value': 100000000, 'currency': '$'},
#   'genres': [{'name': 'вестерн'},
#    {'name': 'боевик'},
#    {'name': 'драма'},
#    {'name': 'комедия'}],
#   'fees': {'world': {'value': 425368238, 'currency': '$'},
#    'russia': {'value': 15990907, 'currency': '$'},
#    'usa': {'value': 162805434, 'currency': '$'}}},
#  {'type': 'movie',
#   'name': 'Бриллиантовая рука',
#   'rating': {'kp': 8.514,
#    'imdb': 8.3,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 643564,
#    'imdb': 15440,
#    'filmCritics': 0,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'distributors': {'distributor': None,
#    'distributorRelease': 'Парадиз, Азимут'},
#   'premiere': {'world': '1969-04-28T00:00:00.000Z'},
#   'year': 1968,
#   'genres': [{'name': 'комедия'}, {'name': 'криминал'}],
#   'budget': {},
#   'fees': {'world': {}, 'russia': {}, 'usa': {}},
#   'movieLength': 94},
#  {'fees': {'world': {'value': 782612155, 'currency': '$'},
#    'russia': {'value': 26120904, 'currency': '$'},
#    'usa': {'value': 363070709, 'currency': '$'}},
#   'rating': {'kp': 7.56,
#    'imdb': 8,
#    'filmCritics': 7.1,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 635929,
#    'imdb': 1068969,
#    'filmCritics': 349,
#    'russianFilmCritics': 16,
#    'await': 84882},
#   'movieLength': 108,
#   'type': 'movie',
#   'name': 'Дэдпул',
#   'distributors': {'distributor': 'Двадцатый Век Фокс СНГ',
#    'distributorRelease': 'НД Плэй'},
#   'premiere': {'world': '2016-01-21T00:00:00.000Z',
#    'russia': '2016-02-11T00:00:00.000Z'},
#   'year': 2016,
#   'budget': {'value': 58000000, 'currency': '$'},
#   'genres': [{'name': 'боевик'}, {'name': 'комедия'}]},
#  {'fees': {'world': {'value': 225508210, 'currency': '$'},
#    'russia': {'value': 11535765, 'currency': '$'},
#    'usa': {'value': 117624357, 'currency': '$'}},
#   'rating': {'kp': 8.239,
#    'imdb': 8.1,
#    'filmCritics': 7.8,
#    'russianFilmCritics': 81.8182,
#    'await': None},
#   'votes': {'kp': 632622,
#    'imdb': 419820,
#    'filmCritics': 361,
#    'russianFilmCritics': 11,
#    'await': 13502},
#   'movieLength': 152,
#   'type': 'movie',
#   'name': 'Ford против Ferrari',
#   'distributors': {'distributor': 'Двадцатый Век Фокс СНГ',
#    'distributorRelease': None},
#   'premiere': {'world': '2019-08-30T00:00:00.000Z',
#    'russia': '2019-11-14T00:00:00.000Z'},
#   'year': 2019,
#   'budget': {'value': 97600000, 'currency': '$'},
#   'genres': [{'name': 'биография'},
#    {'name': 'спорт'},
#    {'name': 'драма'},
#    {'name': 'боевик'}]},
#  {'fees': {'world': {'value': 524028679, 'currency': '$'},
#    'russia': {'value': 16494393, 'currency': '$'},
#    'usa': {'value': 209028679, 'currency': '$'}},
#   'rating': {'kp': 8.063,
#    'imdb': 7.6,
#    'filmCritics': 6.2,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 628309,
#    'imdb': 648618,
#    'filmCritics': 249,
#    'russianFilmCritics': 8,
#    'await': 29387},
#   'movieLength': 128,
#   'type': 'movie',
#   'name': 'Шерлок Холмс',
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2009-12-14T00:00:00.000Z',
#    'russia': '2009-12-31T00:00:00.000Z'},
#   'year': 2009,
#   'budget': {'value': 90000000, 'currency': '$'},
#   'genres': [{'name': 'боевик'},
#    {'name': 'приключения'},
#    {'name': 'триллер'},
#    {'name': 'драма'},
#    {'name': 'комедия'},
#    {'name': 'криминал'},
#    {'name': 'детектив'}]},
#  {'type': 'movie',
#   'name': 'Кавказская пленница, или Новые приключения Шурика',
#   'rating': {'kp': 8.463,
#    'imdb': 8.3,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 624982,
#    'imdb': 12819,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': 0},
#   'distributors': {'distributor': None,
#    'distributorRelease': 'Парадиз, Lizard Cinema Trade'},
#   'premiere': {'world': '1967-04-01T00:00:00.000Z'},
#   'year': 1966,
#   'budget': {'value': 25313, 'currency': 'р.'},
#   'genres': [{'name': 'комедия'},
#    {'name': 'приключения'},
#    {'name': 'мелодрама'},
#    {'name': 'мюзикл'}],
#   'movieLength': 82,
#   'fees': {'world': {}, 'russia': {}, 'usa': {}}},
#  {'fees': {'world': {'value': 460583960, 'currency': '$'},
#    'russia': {'value': 1280000, 'currency': '$'},
#    'usa': {'value': 187705427, 'currency': '$'}},
#   'rating': {'kp': 8.583,
#    'imdb': 8.5,
#    'filmCritics': 7.4,
#    'russianFilmCritics': 50,
#    'await': None},
#   'votes': {'kp': 623527,
#    'imdb': 1537488,
#    'filmCritics': 254,
#    'russianFilmCritics': 4,
#    'await': 1},
#   'movieLength': 155,
#   'type': 'movie',
#   'name': 'Гладиатор',
#   'distributors': {'distributor': 'Ист-Вест',
#    'distributorRelease': 'Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2000-05-01T00:00:00.000Z',
#    'russia': '2000-05-18T00:00:00.000Z'},
#   'year': 2000,
#   'budget': {'value': 103000000, 'currency': '$'},
#   'genres': [{'name': 'история'},
#    {'name': 'боевик'},
#    {'name': 'драма'},
#    {'name': 'приключения'}]},
#  {'fees': {'world': {'value': 898204420, 'currency': '$'},
#    'russia': {'value': 7179834, 'currency': '$'},
#    'usa': {'value': 316115420, 'currency': '$'}},
#   'rating': {'kp': 8.605,
#    'imdb': 8.8,
#    'filmCritics': 8.2,
#    'russianFilmCritics': 71.4286,
#    'await': None},
#   'votes': {'kp': 619868,
#    'imdb': 1917406,
#    'filmCritics': 234,
#    'russianFilmCritics': 7,
#    'await': 0},
#   'movieLength': 178,
#   'type': 'movie',
#   'name': 'Властелин колец: Братство Кольца',
#   'distributors': {'distributor': 'Каро-Премьер, UPI',
#    'distributorRelease': 'Premier Digital, Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2001-12-10T00:00:00.000Z',
#    'russia': '2002-02-07T00:00:00.000Z'},
#   'year': 2001,
#   'budget': {'value': 93000000, 'currency': '$'},
#   'genres': [{'name': 'фэнтези'},
#    {'name': 'приключения'},
#    {'name': 'драма'},
#    {'name': 'боевик'}]},
#  {'fees': {'world': {'value': 381109762, 'currency': '$'},
#    'usa': {'value': 210609762, 'currency': '$'}},
#   'rating': {'kp': 8.644,
#    'imdb': 8.5,
#    'filmCritics': 8.8,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 613482,
#    'imdb': 1240128,
#    'filmCritics': 89,
#    'russianFilmCritics': 2,
#    'await': 1},
#   'movieLength': 116,
#   'type': 'movie',
#   'name': 'Назад в будущее',
#   'distributors': {'distributor': 'Другое кино, Иноекино',
#    'distributorRelease': 'Premier Digital, Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '1985-07-03T00:00:00.000Z',
#    'russia': '2013-06-27T00:00:00.000Z'},
#   'year': 1985,
#   'budget': {'value': 19000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'комедия'},
#    {'name': 'приключения'}]},
#  {'fees': {'world': {'value': 630161890, 'currency': '$'},
#    'usa': {'value': 228433663, 'currency': '$'}},
#   'rating': {'kp': 7.759,
#    'imdb': 8,
#    'filmCritics': 7.9,
#    'russianFilmCritics': 95.2381,
#    'await': None},
#   'votes': {'kp': 611187,
#    'imdb': 880044,
#    'filmCritics': 386,
#    'russianFilmCritics': 21,
#    'await': 59667},
#   'movieLength': 144,
#   'type': 'movie',
#   'name': 'Марсианин',
#   'distributors': {'distributor': 'Двадцатый Век Фокс СНГ',
#    'distributorRelease': None},
#   'premiere': {'world': '2015-09-11T00:00:00.000Z',
#    'russia': '2015-10-08T00:00:00.000Z'},
#   'year': 2015,
#   'budget': {'value': 108000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'}, {'name': 'приключения'}]},
#  {'fees': {'world': {'value': 795634069, 'currency': '$'},
#    'russia': {'value': 7800000, 'currency': '$'},
#    'usa': {'value': 249541069, 'currency': '$'}},
#   'rating': {'kp': 8.221,
#    'imdb': 7.9,
#    'filmCritics': 7.9,
#    'russianFilmCritics': 80,
#    'await': None},
#   'votes': {'kp': 610295,
#    'imdb': 656383,
#    'filmCritics': 259,
#    'russianFilmCritics': 5,
#    'await': 0},
#   'movieLength': 142,
#   'type': 'movie',
#   'name': 'Гарри Поттер и узник Азкабана',
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'Premier Digital, Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2004-05-23T00:00:00.000Z',
#    'russia': '2004-06-03T00:00:00.000Z'},
#   'year': 2004,
#   'budget': {'value': 130000000, 'currency': '$'},
#   'genres': [{'name': 'фэнтези'},
#    {'name': 'приключения'},
#    {'name': 'семейный'}]},
#  {'fees': {'world': {'value': 19552639, 'currency': '$'},
#    'usa': {'value': 19501238, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Леон',
#   'rating': {'kp': 8.668,
#    'imdb': 8.5,
#    'filmCritics': 6.9,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 606620,
#    'imdb': 1189959,
#    'filmCritics': 65,
#    'russianFilmCritics': 2,
#    'await': 0},
#   'distributors': {'distributor': None,
#    'distributorRelease': 'Кармен Видео, CP-Digital'},
#   'premiere': {'world': '1994-09-14T00:00:00.000Z',
#    'russia': '1995-02-27T00:00:00.000Z'},
#   'year': 1994,
#   'budget': {'value': 115000000, 'currency': 'FRF'},
#   'genres': [{'name': 'боевик'},
#    {'name': 'триллер'},
#    {'name': 'драма'},
#    {'name': 'криминал'}],
#   'movieLength': 133},
#  {'fees': {'world': {'value': 585366247, 'currency': '$'},
#    'russia': {'value': 9491200, 'currency': '$'},
#    'usa': {'value': 318604126, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Железный человек',
#   'rating': {'kp': 7.96,
#    'imdb': 7.9,
#    'filmCritics': 7.7,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 605617,
#    'imdb': 1083391,
#    'filmCritics': 282,
#    'russianFilmCritics': 8,
#    'await': 0},
#   'distributors': {'distributor': 'UPI',
#    'distributorRelease': 'Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2008-04-14T00:00:00.000Z',
#    'russia': '2008-05-01T00:00:00.000Z'},
#   'year': 2008,
#   'budget': {'value': 140000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'приключения'}],
#   'movieLength': 121},
#  {'rating': {'kp': 8.137,
#    'imdb': 7.3,
#    'filmCritics': 6,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 602320,
#    'imdb': 737303,
#    'filmCritics': 229,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'movieLength': 151,
#   'type': 'movie',
#   'name': 'Пираты Карибского моря: Сундук мертвеца',
#   'distributors': {'distributor': 'Каскад фильм',
#    'distributorRelease': 'ВС трейд, Уолт Дисней Компани СНГ'},
#   'premiere': {'world': '2006-06-24T00:00:00.000Z',
#    'russia': '2006-07-13T00:00:00.000Z'},
#   'year': 2006,
#   'budget': {'value': 225000000, 'currency': '$'},
#   'genres': [{'name': 'фэнтези'}, {'name': 'боевик'}, {'name': 'приключения'}],
#   'fees': {'world': {'value': 1066179725, 'currency': '$'},
#    'russia': {'value': 27512316, 'currency': '$'},
#    'usa': {'value': 423315812, 'currency': '$'}}},
#  {'fees': {'world': {'value': 351723989, 'currency': '$'},
#    'russia': {'value': 20956962, 'currency': '$'},
#    'usa': {'value': 117723989, 'currency': '$'}},
#   'rating': {'kp': 7.715,
#    'imdb': 7.2,
#    'filmCritics': 5.8,
#    'russianFilmCritics': 60,
#    'await': None},
#   'votes': {'kp': 601320,
#    'imdb': 679055,
#    'filmCritics': 173,
#    'russianFilmCritics': 15,
#    'await': 37930},
#   'movieLength': 115,
#   'type': 'movie',
#   'name': 'Иллюзия обмана',
#   'distributors': {'distributor': 'Централ Партнершип',
#    'distributorRelease': 'CD Land'},
#   'premiere': {'world': '2013-05-21T00:00:00.000Z',
#    'russia': '2013-06-12T00:00:00.000Z'},
#   'year': 2013,
#   'budget': {'value': 75000000, 'currency': '$'},
#   'genres': [{'name': 'криминал'}, {'name': 'триллер'}, {'name': 'детектив'}]},
#  {'fees': {'world': {'value': 214139, 'currency': '$'},
#    'usa': {'value': 5710, 'currency': '$'}},
#   'rating': {'kp': 8.635,
#    'imdb': 7.8,
#    'filmCritics': 0,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 601234,
#    'imdb': 32114,
#    'filmCritics': 0,
#    'russianFilmCritics': 3,
#    'await': 3},
#   'movieLength': 87,
#   'type': 'movie',
#   'name': 'Достучаться до небес',
#   'distributors': {'distributor': 'ОРТ', 'distributorRelease': 'CP-Digital'},
#   'premiere': {'world': '1997-02-20T00:00:00.000Z',
#    'russia': '1997-11-01T00:00:00.000Z'},
#   'year': 1997,
#   'budget': {'value': 4300000, 'currency': 'DEM'},
#   'genres': [{'name': 'драма'}, {'name': 'комедия'}, {'name': 'криминал'}]},
#  {'type': 'movie',
#   'name': 'Москва слезам не верит',
#   'rating': {'kp': 8.424,
#    'imdb': 8.1,
#    'filmCritics': 4.8,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 597425,
#    'imdb': 13591,
#    'filmCritics': 5,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'distributors': {'distributor': None, 'distributorRelease': 'Парадиз'},
#   'premiere': {'world': '1980-02-11T00:00:00.000Z'},
#   'year': 1979,
#   'budget': {'value': 900000, 'currency': '$'},
#   'genres': [{'name': 'мелодрама'}, {'name': 'драма'}, {'name': 'комедия'}],
#   'movieLength': 150,
#   'fees': {'world': {'value': 2516245, 'currency': '$'},
#    'russia': {'value': 17002, 'currency': '$'},
#    'usa': {'value': 2500000, 'currency': '$'}}},
#  {'fees': {'world': {'value': 878979634, 'currency': '$'},
#    'russia': {'value': 8000000, 'currency': '$'},
#    'usa': {'value': 261988482, 'currency': '$'}},
#   'rating': {'kp': 8.123,
#    'imdb': 7.4,
#    'filmCritics': 7.2,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 586782,
#    'imdb': 657368,
#    'filmCritics': 237,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'movieLength': 161,
#   'type': 'movie',
#   'name': 'Гарри Поттер и Тайная комната',
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'Premier Digital, Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2002-11-03T00:00:00.000Z',
#    'russia': '2002-12-26T00:00:00.000Z'},
#   'year': 2002,
#   'budget': {'value': 100000000, 'currency': '$'},
#   'genres': [{'name': 'фэнтези'},
#    {'name': 'приключения'},
#    {'name': 'семейный'}]},
#  {'fees': {'world': {'value': 109676311, 'currency': '$'},
#    'russia': {'value': 1965984, 'currency': '$'},
#    'usa': {'value': 53089891, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Престиж',
#   'rating': {'kp': 8.518,
#    'imdb': 8.5,
#    'filmCritics': 7.1,
#    'russianFilmCritics': 33.3333,
#    'await': None},
#   'votes': {'kp': 581524,
#    'imdb': 1365784,
#    'filmCritics': 204,
#    'russianFilmCritics': 3,
#    'await': 6},
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'Юниверсал Пикчерс Рус, CP-Digital'},
#   'premiere': {'world': '2006-10-17T00:00:00.000Z',
#    'russia': '2007-01-18T00:00:00.000Z'},
#   'year': 2006,
#   'budget': {'value': 40000000, 'currency': '$'},
#   'genres': [{'name': 'триллер'},
#    {'name': 'фантастика'},
#    {'name': 'драма'},
#    {'name': 'детектив'}],
#   'movieLength': 125},
#  {'fees': {'world': {'value': 50263878, 'currency': '$'},
#    'russia': {'value': 62229664, 'currency': '$'}},
#   'rating': {'kp': 6.766,
#    'imdb': 6.7,
#    'filmCritics': 0,
#    'russianFilmCritics': 60,
#    'await': None},
#   'votes': {'kp': 578959,
#    'imdb': 4869,
#    'filmCritics': 0,
#    'russianFilmCritics': 10,
#    'await': 4072},
#   'movieLength': 109,
#   'type': 'movie',
#   'name': 'Холоп',
#   'distributors': {'distributor': 'Централ Партнершип',
#    'distributorRelease': None},
#   'premiere': {'world': '2019-11-24T00:00:00.000Z',
#    'russia': '2019-12-26T00:00:00.000Z'},
#   'year': 2019,
#   'budget': {'value': 160000000, 'currency': '₽'},
#   'genres': [{'name': 'комедия'}, {'name': 'мелодрама'}]},
#  {'fees': {'world': {'value': 263920180, 'currency': '$'},
#    'usa': {'value': 63820180, 'currency': '$'}},
#   'rating': {'kp': 8.112,
#    'imdb': 7.6,
#    'filmCritics': 6.4,
#    'russianFilmCritics': 66.6667,
#    'await': None},
#   'votes': {'kp': 577294,
#    'imdb': 486477,
#    'filmCritics': 68,
#    'russianFilmCritics': 3,
#    'await': 0},
#   'movieLength': 126,
#   'type': 'movie',
#   'name': 'Пятый элемент',
#   'distributors': {'distributor': 'НТВ-Профит',
#    'distributorRelease': 'AMALGAMA, Кармен Видео'},
#   'premiere': {'world': '1997-05-07T00:00:00.000Z',
#    'russia': '1997-09-27T00:00:00.000Z'},
#   'year': 1997,
#   'budget': {'value': 90000000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'боевик'},
#    {'name': 'комедия'},
#    {'name': 'мелодрама'}]},
#  {'fees': {'world': {'value': 321455689, 'currency': '$'},
#    'russia': {'value': 6002703, 'currency': '$'},
#    'usa': {'value': 120540719, 'currency': '$'}},
#   'rating': {'kp': 7.984,
#    'imdb': 8.3,
#    'filmCritics': 7.8,
#    'russianFilmCritics': 80,
#    'await': None},
#   'votes': {'kp': 572814,
#    'imdb': 1493504,
#    'filmCritics': 333,
#    'russianFilmCritics': 10,
#    'await': 13069},
#   'movieLength': 153,
#   'type': 'movie',
#   'name': 'Бесславные ублюдки',
#   'distributors': {'distributor': 'UPI',
#    'distributorRelease': 'Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2009-05-20T00:00:00.000Z',
#    'russia': '2009-08-20T00:00:00.000Z'},
#   'year': 2009,
#   'budget': {'value': 70000000, 'currency': '$'},
#   'genres': [{'name': 'боевик'},
#    {'name': 'драма'},
#    {'name': 'комедия'},
#    {'name': 'военный'}]},
#  {'fees': {'world': {'value': 369330363, 'currency': '$'},
#    'russia': {'value': 11601978, 'currency': '$'},
#    'usa': {'value': 167767189, 'currency': '$'}},
#   'rating': {'kp': 7.959,
#    'imdb': 8.1,
#    'filmCritics': 8,
#    'russianFilmCritics': 96.2963,
#    'await': None},
#   'votes': {'kp': 572512,
#    'imdb': 1009478,
#    'filmCritics': 370,
#    'russianFilmCritics': 27,
#    'await': 32366},
#   'movieLength': 149,
#   'type': 'movie',
#   'name': 'Исчезнувшая',
#   'distributors': {'distributor': 'Двадцатый Век Фокс СНГ',
#    'distributorRelease': 'Двадцатый Век Фокс СНГ'},
#   'premiere': {'world': '2014-09-26T00:00:00.000Z',
#    'russia': '2014-10-02T00:00:00.000Z'},
#   'year': 2014,
#   'budget': {'value': 61000000, 'currency': '$'},
#   'genres': [{'name': 'триллер'}, {'name': 'драма'}, {'name': 'детектив'}]},
#  {'type': 'movie',
#   'name': 'Лига справедливости Зака Снайдера',
#   'rating': {'kp': 7.83,
#    'imdb': 8,
#    'filmCritics': 6.7,
#    'russianFilmCritics': 92.3077,
#    'await': None},
#   'votes': {'kp': 572377,
#    'imdb': 413248,
#    'filmCritics': 308,
#    'russianFilmCritics': 26,
#    'await': 57109},
#   'distributors': {'distributor': None, 'distributorRelease': None},
#   'premiere': {'world': '2021-03-18T00:00:00.000Z'},
#   'year': 2021,
#   'genres': [{'name': 'фантастика'}, {'name': 'боевик'}, {'name': 'фэнтези'}],
#   'budget': {'value': 300000000, 'currency': '$'},
#   'movieLength': 242,
#   'fees': {'world': {}, 'russia': {}, 'usa': {}}},
#  {'fees': {'world': {'value': 126690726, 'currency': '$'},
#    'russia': {'value': 2133270, 'currency': '$'},
#    'usa': {'value': 73357727, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Законопослушный гражданин',
#   'rating': {'kp': 7.999,
#    'imdb': 7.4,
#    'filmCritics': 4.4,
#    'russianFilmCritics': 20,
#    'await': None},
#   'votes': {'kp': 568707,
#    'imdb': 306842,
#    'filmCritics': 162,
#    'russianFilmCritics': 5,
#    'await': 3866},
#   'distributors': {'distributor': 'Top Film Distribution',
#    'distributorRelease': 'Новый Диск, New Dream media'},
#   'premiere': {'world': '2009-09-23T00:00:00.000Z',
#    'russia': '2009-11-04T00:00:00.000Z'},
#   'year': 2009,
#   'budget': {'value': 50000000, 'currency': '$'},
#   'genres': [{'name': 'боевик'},
#    {'name': 'триллер'},
#    {'name': 'драма'},
#    {'name': 'криминал'}],
#   'movieLength': 108},
#  {'type': 'movie',
#   'name': 'Главный герой',
# ...
#   'movieLength': 118,
#   'type': 'movie',
#   'name': 'Лев',
#   'distributors': {'distributor': 'Capella Film',
#    'distributorRelease': 'НД Плэй'},
#   'premiere': {'world': '2016-09-10T00:00:00.000Z',
#    'russia': '2017-02-16T00:00:00.000Z'},
#   'year': 2016,
#   'budget': {'value': 12000000, 'currency': '$'},
#   'genres': [{'name': 'драма'}, {'name': 'биография'}]},
#  {'fees': {'world': {'value': 88528280, 'currency': '$'},
#    'russia': {'value': 3597502, 'currency': '$'},
#    'usa': {'value': 31016021, 'currency': '$'}},
#   'rating': {'kp': 7.152,
#    'imdb': 6.8,
#    'filmCritics': 3.7,
#    'russianFilmCritics': 62.5,
#    'await': None},
#   'votes': {'kp': 130401,
#    'imdb': 102777,
#    'filmCritics': 188,
#    'russianFilmCritics': 8,
#    'await': 16040},
#   'movieLength': 97,
#   'type': 'movie',
#   'name': 'Призрачная красота',
#   'distributors': {'distributor': 'Каро-Премьер', 'distributorRelease': None},
#   'premiere': {'world': '2016-12-12T00:00:00.000Z',
#    'russia': '2016-12-15T00:00:00.000Z'},
#   'year': 2016,
#   'budget': {'value': 36000000, 'currency': '$'},
#   'genres': [{'name': 'драма'}, {'name': 'мелодрама'}]},
#  {'type': 'movie',
#   'name': 'Хроники Нарнии: Покоритель Зари',
#   'rating': {'kp': 6.892,
#    'imdb': 6.3,
#    'filmCritics': 5.7,
#    'russianFilmCritics': 83.3333,
#    'await': None},
#   'votes': {'kp': 130375,
#    'imdb': 159570,
#    'filmCritics': 167,
#    'russianFilmCritics': 6,
#    'await': 33916},
#   'distributors': {'distributor': 'Двадцатый Век Фокс СНГ',
#    'distributorRelease': 'Двадцатый Век Фокс СНГ'},
#   'premiere': {'world': '2010-12-02T00:00:00.000Z',
#    'russia': '2010-12-09T00:00:00.000Z'},
#   'year': 2010,
#   'budget': {'value': 155000000, 'currency': '$'},
#   'genres': [{'name': 'фэнтези'},
#    {'name': 'приключения'},
#    {'name': 'семейный'}],
#   'movieLength': 112,
#   'fees': {'world': {'value': 415686217, 'currency': '$'},
#    'russia': {'value': 18981876, 'currency': '$'},
#    'usa': {'value': 104386950, 'currency': '$'}}},
#  {'fees': {'world': {'value': 65754228, 'currency': '$'},
#    'usa': {'value': 25288103, 'currency': '$'}},
#   'rating': {'kp': 7.741,
#    'imdb': 6.7,
#    'filmCritics': 3.6,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 130236,
#    'imdb': 92547,
#    'filmCritics': 99,
#    'russianFilmCritics': 4,
#    'await': 0},
#   'movieLength': 119,
#   'type': 'movie',
#   'name': 'Сладкий ноябрь',
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'Мост-Видео'},
#   'premiere': {'world': '2001-02-12T00:00:00.000Z',
#    'russia': '2001-11-15T00:00:00.000Z'},
#   'year': 2001,
#   'budget': {'value': 40000000, 'currency': '$'},
#   'genres': [{'name': 'драма'}, {'name': 'мелодрама'}]},
#  {'rating': {'kp': 7.778,
#    'imdb': 6.8,
#    'filmCritics': 5.5,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 130020,
#    'imdb': 114184,
#    'filmCritics': 130,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'movieLength': 125,
#   'type': 'movie',
#   'name': 'Семьянин',
#   'distributors': {'distributor': 'Гемини',
#    'distributorRelease': 'CP-Digital'},
#   'premiere': {'world': '2000-12-12T00:00:00.000Z',
#    'russia': '2001-02-22T00:00:00.000Z'},
#   'year': 2000,
#   'budget': {'value': 60000000, 'currency': '$'},
#   'genres': [{'name': 'фэнтези'},
#    {'name': 'драма'},
#    {'name': 'мелодрама'},
#    {'name': 'комедия'}],
#   'fees': {'world': {'value': 124745083, 'currency': '$'},
#    'russia': {'value': 258127, 'currency': '$'},
#    'usa': {'value': 75793305, 'currency': '$'}}},
#  {'genres': [{'name': 'фэнтези'}, {'name': 'драма'}, {'name': 'комедия'}],
#   'movieLength': 134,
#   'name': 'Тот самый Мюнхгаузен',
#   'rating': {'kp': 8.311,
#    'imdb': 8.4,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'type': 'movie',
#   'votes': {'kp': 129655,
#    'imdb': 3733,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': 0},
#   'year': 1979,
#   'premiere': {'world': '1980-01-01T00:00:00.000Z'},
#   'fees': {'world': {}, 'russia': {}, 'usa': {}},
#   'budget': {}},
#  {'fees': {'world': {'value': 176070171, 'currency': '$'},
#    'russia': {'value': 1148480, 'currency': '$'},
#    'usa': {'value': 106128601, 'currency': '$'}},
#   'rating': {'kp': 7.578,
#    'imdb': 7,
#    'filmCritics': 6.4,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 129653,
#    'imdb': 377436,
#    'filmCritics': 182,
#    'russianFilmCritics': 0,
#    'await': 0},
#   'movieLength': 111,
#   'type': 'movie',
#   'name': 'Ограбление по-итальянски',
#   'distributors': {'distributor': 'Ист-Вест',
#    'distributorRelease': 'Юниверсал Пикчерс Рус'},
#   'premiere': {'world': '2003-05-30T00:00:00.000Z',
#    'russia': '2003-09-18T00:00:00.000Z'},
#   'year': 2003,
#   'budget': {'value': 60000000, 'currency': '$'},
#   'genres': [{'name': 'боевик'}, {'name': 'триллер'}, {'name': 'криминал'}]},
#  {'fees': {'world': {'value': 203277636, 'currency': '$'},
#    'russia': {'value': 13802731, 'currency': '$'},
#    'usa': {'value': 43577636, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Need for Speed: Жажда скорости',
#   'rating': {'kp': 6.843,
#    'imdb': 6.4,
#    'filmCritics': 4.3,
#    'russianFilmCritics': 55.5556,
#    'await': None},
#   'votes': {'kp': 129519,
#    'imdb': 174378,
#    'filmCritics': 187,
#    'russianFilmCritics': 9,
#    'await': 23506},
#   'distributors': {'distributor': 'WDSSPR',
#    'distributorRelease': 'Уолт Дисней Компани СНГ'},
#   'premiere': {'world': '2014-03-07T00:00:00.000Z',
#    'russia': '2014-03-13T00:00:00.000Z'},
#   'year': 2014,
#   'budget': {'value': 66000000, 'currency': '$'},
#   'genres': [{'name': 'боевик'}, {'name': 'триллер'}],
#   'movieLength': 130},
#  {'rating': {'kp': 6.435,
#    'imdb': 6.5,
#    'filmCritics': 7.5,
#    'russianFilmCritics': 85.7143,
#    'await': None},
#   'votes': {'kp': 129346,
#    'imdb': 247311,
#    'filmCritics': 398,
#    'russianFilmCritics': 7,
#    'await': 19357},
#   'movieLength': 123,
#   'type': 'movie',
#   'name': 'К звёздам',
#   'distributors': {'distributor': 'Двадцатый Век Фокс СНГ',
#    'distributorRelease': None},
#   'premiere': {'world': '2019-08-29T00:00:00.000Z',
#    'russia': '2019-09-26T00:00:00.000Z'},
#   'year': 2019,
#   'budget': {'value': 87500000, 'currency': '$'},
#   'genres': [{'name': 'фантастика'},
#    {'name': 'триллер'},
#    {'name': 'драма'},
#    {'name': 'детектив'},
#    {'name': 'приключения'}],
#   'fees': {'world': {'value': 127461872, 'currency': '$'},
#    'russia': {'value': 5492557, 'currency': '$'},
#    'usa': {'value': 50188370, 'currency': '$'}}},
#  {'fees': {'world': {'value': 1644060, 'currency': '$'},
#    'usa': {'value': 1644060, 'currency': '$'}},
#   'rating': {'kp': 7.302,
#    'imdb': 5.9,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 129282,
#    'imdb': 43870,
#    'filmCritics': 0,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'movieLength': 109,
#   'type': 'movie',
#   'name': 'Астерикс и Обеликс против Цезаря',
#   'distributors': {'distributor': 'Централ Партнершип',
#    'distributorRelease': 'CP-Digital'},
#   'premiere': {'world': '1999-02-03T00:00:00.000Z',
#    'russia': '2000-10-19T00:00:00.000Z'},
#   'year': 1999,
#   'budget': {'value': 274620000, 'currency': 'FRF'},
#   'genres': [{'name': 'фэнтези'},
#    {'name': 'комедия'},
#    {'name': 'приключения'},
#    {'name': 'семейный'}]},
#  {'fees': {'world': {'value': 89792502, 'currency': '$'},
#    'russia': {'value': 3928133, 'currency': '$'},
#    'usa': {'value': 36392502, 'currency': '$'}},
#   'rating': {'kp': 6.55,
#    'imdb': 6,
#    'filmCritics': 4.2,
#    'russianFilmCritics': 44.4444,
#    'await': None},
#   'votes': {'kp': 129236,
#    'imdb': 246674,
#    'filmCritics': 218,
#    'russianFilmCritics': 9,
#    'await': 27263},
#   'movieLength': 110,
#   'type': 'movie',
#   'name': 'Запрещенный прием',
#   'distributors': {'distributor': 'Каро-Премьер',
#    'distributorRelease': 'CP-Digital'},
#   'premiere': {'world': '2011-03-21T00:00:00.000Z',
#    'russia': '2011-03-31T00:00:00.000Z'},
#   'year': 2011,
#   'budget': {'value': 82000000, 'currency': '$'},
#   'genres': [{'name': 'фэнтези'},
#    {'name': 'боевик'},
#    {'name': 'приключения'}]},
#  {'genres': [{'name': 'мюзикл'},
#    {'name': 'фантастика'},
#    {'name': 'мелодрама'},
#    {'name': 'комедия'}],
#   'movieLength': 147,
#   'name': 'Чародеи',
#   'rating': {'kp': 7.974,
#    'imdb': 7.1,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'type': 'movie',
#   'votes': {'kp': 129223,
#    'imdb': 1940,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': 0},
#   'year': 1982,
#   'premiere': {'world': '1982-12-31T00:00:00.000Z'},
#   'budget': {},
#   'fees': {'world': {}, 'russia': {}, 'usa': {}}},
#  {'fees': {'world': {'value': 361336633, 'currency': '$'},
#    'russia': {'value': 2686000, 'currency': '$'},
#    'usa': {'value': 217326974, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Элвин и бурундуки',
#   'rating': {'kp': 6.241,
#    'imdb': 5.2,
#    'filmCritics': 4.5,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 128998,
#    'imdb': 90120,
#    'filmCritics': 109,
#    'russianFilmCritics': 1,
#    'await': 0},
#   'distributors': {'distributor': 'Фокс/Гемини',
#    'distributorRelease': 'Двадцатый Век Фокс СНГ'},
#   'premiere': {'world': '2007-12-13T00:00:00.000Z',
#    'russia': '2007-12-20T00:00:00.000Z'},
#   'year': 2007,
#   'budget': {'value': 60000000, 'currency': '$'},
#   'genres': [{'name': 'семейный'}, {'name': 'комедия'}, {'name': 'музыка'}],
#   'movieLength': 87},
#  {'fees': {'world': {'value': 162360636, 'currency': '$'},
#    'russia': {'value': 3518971, 'currency': '$'},
#    'usa': {'value': 93432655, 'currency': '$'}},
#   'rating': {'kp': 6.839,
#    'imdb': 6.9,
#    'filmCritics': 6,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 128874,
#    'imdb': 219491,
#    'filmCritics': 317,
#    'russianFilmCritics': 18,
#    'await': 18977},
#   'movieLength': 132,
#   'type': 'movie',
#   'name': 'Великолепная семерка',
#   'distributors': {'distributor': 'WDSSPR', 'distributorRelease': None},
#   'premiere': {'world': '2016-09-08T00:00:00.000Z',
#    'russia': '2016-09-22T00:00:00.000Z'},
#   'year': 2016,
#   'budget': {'value': 90000000, 'currency': '$'},
#   'genres': [{'name': 'вестерн'},
#    {'name': 'боевик'},
#    {'name': 'приключения'}]},
#  {'fees': {'world': {'value': 5184368, 'currency': '$'},
#    'russia': {'value': 906645, 'currency': '$'}},
#   'rating': {'kp': 6.819,
#    'imdb': 6.7,
#    'filmCritics': 7.1,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 128857,
#    'imdb': 86935,
#    'filmCritics': 141,
#    'russianFilmCritics': 1,
#    'await': 1518},
#   'movieLength': 90,
#   'type': 'movie',
#   'name': 'Взаперти',
#   'distributors': {'distributor': 'Централ Партнершип',
#    'distributorRelease': None},
#   'premiere': {'world': '2020-04-13T00:00:00.000Z',
#    'russia': '2020-11-20T00:00:00.000Z'},
#   'year': 2020,
#   'genres': [{'name': 'триллер'}, {'name': 'драма'}, {'name': 'детектив'}],
#   'budget': {}},
#  {'fees': {'world': {'value': 84872444, 'currency': '$'},
#    'russia': {'value': 339682, 'currency': '$'},
#    'usa': {'value': 46889293, 'currency': '$'}},
#   'rating': {'kp': 7.176,
#    'imdb': 7.6,
#    'filmCritics': 8.1,
#    'russianFilmCritics': 91.6667,
#    'await': None},
#   'votes': {'kp': 128849,
#    'imdb': 446715,
#    'filmCritics': 283,
#    'russianFilmCritics': 12,
#    'await': 2283},
#   'movieLength': 121,
#   'type': 'movie',
#   'name': 'Убийца',
#   'distributors': {'distributor': 'WDSSPR', 'distributorRelease': None},
#   'premiere': {'world': '2015-05-19T00:00:00.000Z',
#    'russia': '2015-11-26T00:00:00.000Z'},
#   'year': 2015,
#   'budget': {'value': 30000000, 'currency': '$'},
#   'genres': [{'name': 'боевик'},
#    {'name': 'триллер'},
#    {'name': 'драма'},
#    {'name': 'криминал'},
#    {'name': 'детектив'}]},
#  {'fees': {'world': {'value': 145374099, 'currency': '$'},
#    'russia': {'value': 1982873, 'currency': '$'},
#    'usa': {'value': 34393507, 'currency': '$'}},
#   'rating': {'kp': 7.234,
#    'imdb': 7,
#    'filmCritics': 6,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 128846,
#    'imdb': 118498,
#    'filmCritics': 127,
#    'russianFilmCritics': 5,
#    'await': 6328},
#   'movieLength': 113,
#   'type': 'movie',
#   'name': 'Иностранец',
#   'distributors': {'distributor': 'Парадиз', 'distributorRelease': None},
#   'premiere': {'world': '2017-09-24T00:00:00.000Z',
#    'russia': '2017-11-30T00:00:00.000Z'},
#   'year': 2017,
#   'budget': {'value': 35000000, 'currency': '$'},
#   'genres': [{'name': 'боевик'}, {'name': 'триллер'}, {'name': 'детектив'}]},
#  {'rating': {'kp': 7.644,
#    'imdb': 8.1,
#    'filmCritics': 8.5,
#    'russianFilmCritics': 100,
#    'await': None},
#   'votes': {'kp': 128757,
#    'imdb': 432110,
#    'filmCritics': 319,
#    'russianFilmCritics': 7,
#    'await': 439},
#   'movieLength': 118,
#   'type': 'movie',
#   'name': 'Комната',
#   'distributors': {'distributor': 'Capella Film', 'distributorRelease': None},
#   'premiere': {'world': '2015-09-04T00:00:00.000Z',
#    'russia': '2020-08-27T00:00:00.000Z'},
#   'year': 2015,
#   'budget': {'value': 13000000, 'currency': '$'},
#   'genres': [{'name': 'триллер'}, {'name': 'драма'}],
#   'fees': {'world': {'value': 35401758, 'currency': '$'},
#    'russia': {'value': 15314, 'currency': '$'},
#    'usa': {'value': 14677654, 'currency': '$'}}},
#  {'rating': {'kp': 6.522,
#    'imdb': 6.1,
#    'filmCritics': 4.3,
#    'russianFilmCritics': 50,
#    'await': None},
#   'votes': {'kp': 128586,
#    'imdb': 99790,
#    'filmCritics': 192,
#    'russianFilmCritics': 4,
#    'await': 14202},
#   'movieLength': 100,
#   'type': 'movie',
#   'name': 'Телохранитель жены киллера',
#   'distributors': {'distributor': 'MEGOGO Distribution',
#    'distributorRelease': None},
#   'premiere': {'world': '2021-06-10T00:00:00.000Z',
#    'russia': '2021-06-16T00:00:00.000Z'},
#   'year': 2020,
#   'genres': [{'name': 'боевик'}, {'name': 'комедия'}],
#   'budget': {'value': 70000000, 'currency': '$'},
#   'fees': {'world': {'value': 70060492, 'currency': '$'},
#    'russia': {'value': 4168100, 'currency': '$'},
#    'usa': {'value': 38014727, 'currency': '$'}}},
#  {'fees': {'world': {'value': 10433259, 'currency': '$'},
#    'russia': {'value': 10796309, 'currency': '$'},
#    'usa': {'value': 9996, 'currency': '$'}},
#   'rating': {'kp': 6.779,
#    'imdb': 6.2,
#    'filmCritics': 0,
#    'russianFilmCritics': 75,
#    'await': None},
#   'votes': {'kp': 128563,
#    'imdb': 3666,
#    'filmCritics': 0,
#    'russianFilmCritics': 12,
#    'await': 7108},
#   'movieLength': 117,
#   'type': 'movie',
#   'name': 'Легенда о Коловрате',
#   'distributors': {'distributor': 'Централ Партнершип',
#    'distributorRelease': None},
#   'premiere': {'world': '2017-11-30T00:00:00.000Z',
#    'russia': '2017-11-30T00:00:00.000Z'},
#   'year': 2017,
#   'budget': {'value': 360000000, 'currency': '₽'},
#   'genres': [{'name': 'история'}, {'name': 'боевик'}, {'name': 'фэнтези'}]},
#  {'rating': {'kp': 8.051,
#    'imdb': 7.6,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': None},
#   'votes': {'kp': 128421,
#    'imdb': 3385,
#    'filmCritics': 0,
#    'russianFilmCritics': 0,
#    'await': 0},
#   'movieLength': 98,
#   'type': 'movie',
#   'name': 'Человек с бульвара Капуцинов',
#   'distributors': {'distributor': None,
#    'distributorRelease': 'Парадиз, Цифровой Элемент'},
#   'premiere': {'world': '1987-06-23T00:00:00.000Z'},
#   'year': 1987,
#   'budget': {'value': 750000, 'currency': '₽'},
#   'genres': [{'name': 'вестерн'},
#    {'name': 'комедия'},
#    {'name': 'мюзикл'},
#    {'name': 'мелодрама'}],
#   'fees': {'world': {}, 'russia': {}, 'usa': {}}},
#  {'fees': {'world': {'value': 157761002, 'currency': '$'},
#    'usa': {'value': 89217875, 'currency': '$'}},
#   'type': 'movie',
#   'name': 'Не дыши',
#   'rating': {'kp': 6.65,
#    'imdb': 7.1,
#    'filmCritics': 7.3,
#    'russianFilmCritics': 90,
#    'await': None},
#   'votes': {'kp': 128363,
#    'imdb': 286050,
#    'filmCritics': 245,
#    'russianFilmCritics': 10,
#    'await': 4799},
#   'distributors': {'distributor': 'WDSSPR', 'distributorRelease': None},
#   'premiere': {'world': '2016-03-12T00:00:00.000Z',
#    'russia': '2016-08-25T00:00:00.000Z'},
#   'year': 2015,
#   'budget': {'value': 9900000, 'currency': '$'},
#   'genres': [{'name': 'триллер'}, {'name': 'криминал'}],
#   'movieLength': 88},
#  ...]

# %% [markdown]
# Создадим датафрейм с данными:

# %%
import pandas as pd
df_l = pd.json_normalize(dict)
df_l
# Out:
#       movieLength   type                    name  year  \
# 0           112.0  movie                     1+1  2011
# 1           113.0  movie             Джентльмены  2019
# 2           180.0  movie       Волк с Уолл-стрит  2013
# 3           119.0  movie       Гнев человеческий  2021
# 4           100.0  movie                    Брат  1997
# ...           ...    ...                     ...   ...
# 3995         95.0  movie             Короли лета  2013
# 3996        116.0  movie  Lil Peep: всё для всех  2019
# 3997         85.0  movie                 Фантомы  2008
# 3998        103.0  movie                   Выход  2019
# 3999        103.0  movie        Мечты сбываются!  2013
#
#                                                  genres  fees.world.value  \
# 0     [{'name': 'драма'}, {'name': 'комедия'}, {'nam...       426588510.0
# 1     [{'name': 'криминал'}, {'name': 'комедия'}, {'...       115171795.0
# 2     [{'name': 'драма'}, {'name': 'криминал'}, {'na...       392000694.0
# 3             [{'name': 'боевик'}, {'name': 'триллер'}]       103966489.0
# 4     [{'name': 'драма'}, {'name': 'криминал'}, {'na...         1362281.0
# ...                                                 ...               ...
# 3995  [{'name': 'драма'}, {'name': 'комедия'}, {'nam...         1501595.0
# 3996   [{'name': 'документальный'}, {'name': 'музыка'}]          748539.0
# 3997                                [{'name': 'ужасы'}]        48555306.0
# 3998          [{'name': 'боевик'}, {'name': 'комедия'}]        79410586.0
# 3999  [{'name': 'драма'}, {'name': 'комедия'}, {'nam...        10900434.0
#
#      fees.world.currency  fees.russia.value fees.russia.currency  \
# 0                      $          1725813.0                    $
# 1                      $         18003343.0                    $
# 2                      $         13796916.0                    $
# 3                      $         13318455.0                    $
# 4                      $                NaN                  NaN
# ...                  ...                ...                  ...
# 3995                   $             4252.0                    $
# 3996                   $           198254.0                    $
# 3997                   $          1811000.0                    $
# 3998                   $                NaN                  NaN
# 3999                   $                NaN                  NaN
#
#       fees.usa.value  ... votes.russianFilmCritics  votes.await  \
# 0         10198820.0  ...                       12           15
# 1         36471795.0  ...                       22        13642
# 2        116900694.0  ...                       31        43024
# 3         27466489.0  ...                       37        23492
# 4                NaN  ...                        2            0
# ...              ...  ...                      ...          ...
# 3995       1315590.0  ...                        1          232
# 3996        547207.0  ...                        6          262
# 3997      25928550.0  ...                        1            0
# 3998        470699.0  ...                        0           37
# 3999        101196.0  ...                        0          498
#
#       distributors.distributor  distributors.distributorRelease  \
# 0                 Каскад фильм                       Новый Диск
# 1                       Вольга                             None
# 2                         West                       West Video
# 3                       Вольга                             None
# 4          Кармен-Премьер, СТВ                       Союз-Видео
# ...                        ...                              ...
# 3995          All Media, Арена                             None
# 3996               A-One Films                             None
# 3997    Двадцатый Век Фокс СНГ           Двадцатый Век Фокс СНГ
# 3998                      None                             None
# 3999                      None                           Вольга
#
#                 premiere.world           premiere.russia  budget.value  \
# 0     2011-09-23T00:00:00.000Z  2012-04-26T00:00:00.000Z     9500000.0
# 1     2019-12-03T00:00:00.000Z  2020-02-13T00:00:00.000Z    22000000.0
# 2     2013-12-09T00:00:00.000Z  2014-02-06T00:00:00.000Z   100000000.0
# 3     2021-04-22T00:00:00.000Z  2021-04-22T00:00:00.000Z    40000000.0
# 4     1997-05-17T00:00:00.000Z  1997-12-12T00:00:00.000Z           NaN
# ...                        ...                       ...           ...
# 3995  2013-01-19T00:00:00.000Z  2013-10-03T00:00:00.000Z           NaN
# 3996  2019-01-10T00:00:00.000Z  2019-11-21T00:00:00.000Z           NaN
# 3997  2008-03-19T00:00:00.000Z  2008-04-03T00:00:00.000Z     8000000.0
# 3998  2019-07-31T00:00:00.000Z                       NaN    11500000.0
# 3999  2013-09-09T00:00:00.000Z                       NaN           NaN
#
#       budget.currency  premiere.digital  premiere.dvd
# 0                   €               NaN           NaN
# 1                   $               NaN           NaN
# 2                   $               NaN           NaN
# 3                   $               NaN           NaN
# 4                 NaN               NaN           NaN
# ...               ...               ...           ...
# 3995              NaN               NaN           NaN
# 3996              NaN               NaN           NaN
# 3997                $               NaN           NaN
# 3998                $               NaN           NaN
# 3999              NaN               NaN           NaN
#
# [4000 rows x 29 columns]

# %% [markdown]
# ## Шаг 3: Предварительныя обработка (максимум 10 баллов)

# %% [markdown]
# Теперь займемся обработкой данных.

# %% [markdown]
# ### 1. Поработаем с форматом переменных:
# Преобразуем столбец с жанрами в список, чтобы было удобнее работать:

# %%
import re
df_l['genres'] = df_l['genres'].apply(lambda x: re.findall(r"'name': '([^']*)'", str(x)))

# %%
df_l
# Out:
#       movieLength   type                    name  year  \
# 0           112.0  movie                     1+1  2011
# 1           113.0  movie             Джентльмены  2019
# 2           180.0  movie       Волк с Уолл-стрит  2013
# 3           119.0  movie       Гнев человеческий  2021
# 4           100.0  movie                    Брат  1997
# ...           ...    ...                     ...   ...
# 3995         95.0  movie             Короли лета  2013
# 3996        116.0  movie  Lil Peep: всё для всех  2019
# 3997         85.0  movie                 Фантомы  2008
# 3998        103.0  movie                   Выход  2019
# 3999        103.0  movie        Мечты сбываются!  2013
#
#                                       genres  fees.world.value  \
# 0                [драма, комедия, биография]       426588510.0
# 1                [криминал, комедия, боевик]       115171795.0
# 2      [драма, криминал, биография, комедия]       392000694.0
# 3                          [боевик, триллер]       103966489.0
# 4                  [драма, криминал, боевик]         1362281.0
# ...                                      ...               ...
# 3995           [драма, комедия, приключения]         1501595.0
# 3996                [документальный, музыка]          748539.0
# 3997                                 [ужасы]        48555306.0
# 3998                       [боевик, комедия]        79410586.0
# 3999  [драма, комедия, мелодрама, биография]        10900434.0
#
#      fees.world.currency  fees.russia.value fees.russia.currency  \
# 0                      $          1725813.0                    $
# 1                      $         18003343.0                    $
# 2                      $         13796916.0                    $
# 3                      $         13318455.0                    $
# 4                      $                NaN                  NaN
# ...                  ...                ...                  ...
# 3995                   $             4252.0                    $
# 3996                   $           198254.0                    $
# 3997                   $          1811000.0                    $
# 3998                   $                NaN                  NaN
# 3999                   $                NaN                  NaN
#
#       fees.usa.value  ... votes.russianFilmCritics  votes.await  \
# 0         10198820.0  ...                       12           15
# 1         36471795.0  ...                       22        13642
# 2        116900694.0  ...                       31        43024
# 3         27466489.0  ...                       37        23492
# 4                NaN  ...                        2            0
# ...              ...  ...                      ...          ...
# 3995       1315590.0  ...                        1          232
# 3996        547207.0  ...                        6          262
# 3997      25928550.0  ...                        1            0
# 3998        470699.0  ...                        0           37
# 3999        101196.0  ...                        0          498
#
#       distributors.distributor  distributors.distributorRelease  \
# 0                 Каскад фильм                       Новый Диск
# 1                       Вольга                             None
# 2                         West                       West Video
# 3                       Вольга                             None
# 4          Кармен-Премьер, СТВ                       Союз-Видео
# ...                        ...                              ...
# 3995          All Media, Арена                             None
# 3996               A-One Films                             None
# 3997    Двадцатый Век Фокс СНГ           Двадцатый Век Фокс СНГ
# 3998                      None                             None
# 3999                      None                           Вольга
#
#                 premiere.world           premiere.russia  budget.value  \
# 0     2011-09-23T00:00:00.000Z  2012-04-26T00:00:00.000Z     9500000.0
# 1     2019-12-03T00:00:00.000Z  2020-02-13T00:00:00.000Z    22000000.0
# 2     2013-12-09T00:00:00.000Z  2014-02-06T00:00:00.000Z   100000000.0
# 3     2021-04-22T00:00:00.000Z  2021-04-22T00:00:00.000Z    40000000.0
# 4     1997-05-17T00:00:00.000Z  1997-12-12T00:00:00.000Z           NaN
# ...                        ...                       ...           ...
# 3995  2013-01-19T00:00:00.000Z  2013-10-03T00:00:00.000Z           NaN
# 3996  2019-01-10T00:00:00.000Z  2019-11-21T00:00:00.000Z           NaN
# 3997  2008-03-19T00:00:00.000Z  2008-04-03T00:00:00.000Z     8000000.0
# 3998  2019-07-31T00:00:00.000Z                       NaN    11500000.0
# 3999  2013-09-09T00:00:00.000Z                       NaN           NaN
#
#       budget.currency  premiere.digital  premiere.dvd
# 0                   €               NaN           NaN
# 1                   $               NaN           NaN
# 2                   $               NaN           NaN
# 3                   $               NaN           NaN
# 4                 NaN               NaN           NaN
# ...               ...               ...           ...
# 3995              NaN               NaN           NaN
# 3996              NaN               NaN           NaN
# 3997                $               NaN           NaN
# 3998                $               NaN           NaN
# 3999              NaN               NaN           NaN
#
# [4000 rows x 29 columns]

# %% [markdown]
# Далее преобразуем столбцы с датами в более удобный формат datetime:

# %%
df_l['premiere.world'] = pd.to_datetime(df_l['premiere.world'])
df_l['premiere.russia'] = pd.to_datetime(df_l['premiere.russia'])

# %%
df_l
# Out:
#       movieLength   type                    name  year  \
# 0           112.0  movie                     1+1  2011
# 1           113.0  movie             Джентльмены  2019
# 2           180.0  movie       Волк с Уолл-стрит  2013
# 3           119.0  movie       Гнев человеческий  2021
# 4           100.0  movie                    Брат  1997
# ...           ...    ...                     ...   ...
# 3995         95.0  movie             Короли лета  2013
# 3996        116.0  movie  Lil Peep: всё для всех  2019
# 3997         85.0  movie                 Фантомы  2008
# 3998        103.0  movie                   Выход  2019
# 3999        103.0  movie        Мечты сбываются!  2013
#
#                                       genres  fees.world.value  \
# 0                [драма, комедия, биография]       426588510.0
# 1                [криминал, комедия, боевик]       115171795.0
# 2      [драма, криминал, биография, комедия]       392000694.0
# 3                          [боевик, триллер]       103966489.0
# 4                  [драма, криминал, боевик]         1362281.0
# ...                                      ...               ...
# 3995           [драма, комедия, приключения]         1501595.0
# 3996                [документальный, музыка]          748539.0
# 3997                                 [ужасы]        48555306.0
# 3998                       [боевик, комедия]        79410586.0
# 3999  [драма, комедия, мелодрама, биография]        10900434.0
#
#      fees.world.currency  fees.russia.value fees.russia.currency  \
# 0                      $          1725813.0                    $
# 1                      $         18003343.0                    $
# 2                      $         13796916.0                    $
# 3                      $         13318455.0                    $
# 4                      $                NaN                  NaN
# ...                  ...                ...                  ...
# 3995                   $             4252.0                    $
# 3996                   $           198254.0                    $
# 3997                   $          1811000.0                    $
# 3998                   $                NaN                  NaN
# 3999                   $                NaN                  NaN
#
#       fees.usa.value  ... votes.russianFilmCritics  votes.await  \
# 0         10198820.0  ...                       12           15
# 1         36471795.0  ...                       22        13642
# 2        116900694.0  ...                       31        43024
# 3         27466489.0  ...                       37        23492
# 4                NaN  ...                        2            0
# ...              ...  ...                      ...          ...
# 3995       1315590.0  ...                        1          232
# 3996        547207.0  ...                        6          262
# 3997      25928550.0  ...                        1            0
# 3998        470699.0  ...                        0           37
# 3999        101196.0  ...                        0          498
#
#       distributors.distributor  distributors.distributorRelease  \
# 0                 Каскад фильм                       Новый Диск
# 1                       Вольга                             None
# 2                         West                       West Video
# 3                       Вольга                             None
# 4          Кармен-Премьер, СТВ                       Союз-Видео
# ...                        ...                              ...
# 3995          All Media, Арена                             None
# 3996               A-One Films                             None
# 3997    Двадцатый Век Фокс СНГ           Двадцатый Век Фокс СНГ
# 3998                      None                             None
# 3999                      None                           Вольга
#
#                 premiere.world           premiere.russia  budget.value  \
# 0    2011-09-23 00:00:00+00:00 2012-04-26 00:00:00+00:00     9500000.0
# 1    2019-12-03 00:00:00+00:00 2020-02-13 00:00:00+00:00    22000000.0
# 2    2013-12-09 00:00:00+00:00 2014-02-06 00:00:00+00:00   100000000.0
# 3    2021-04-22 00:00:00+00:00 2021-04-22 00:00:00+00:00    40000000.0
# 4    1997-05-17 00:00:00+00:00 1997-12-12 00:00:00+00:00           NaN
# ...                        ...                       ...           ...
# 3995 2013-01-19 00:00:00+00:00 2013-10-03 00:00:00+00:00           NaN
# 3996 2019-01-10 00:00:00+00:00 2019-11-21 00:00:00+00:00           NaN
# 3997 2008-03-19 00:00:00+00:00 2008-04-03 00:00:00+00:00     8000000.0
# 3998 2019-07-31 00:00:00+00:00                       NaT    11500000.0
# 3999 2013-09-09 00:00:00+00:00                       NaT           NaN
#
#       budget.currency  premiere.digital  premiere.dvd
# 0                   €               NaN           NaN
# 1                   $               NaN           NaN
# 2                   $               NaN           NaN
# 3                   $               NaN           NaN
# 4                 NaN               NaN           NaN
# ...               ...               ...           ...
# 3995              NaN               NaN           NaN
# 3996              NaN               NaN           NaN
# 3997                $               NaN           NaN
# 3998                $               NaN           NaN
# 3999              NaN               NaN           NaN
#
# [4000 rows x 29 columns]

# %%
df_l.dtypes
# Out:
# movieLength                                    float64
# type                                            object
# name                                            object
# year                                             int64
# genres                                          object
# fees.world.value                               float64
# fees.world.currency                             object
# fees.russia.value                              float64
# fees.russia.currency                            object
# fees.usa.value                                 float64
# fees.usa.currency                               object
# rating.kp                                      float64
# rating.imdb                                    float64
# rating.filmCritics                             float64
# rating.russianFilmCritics                      float64
# rating.await                                   float64
# votes.kp                                         int64
# votes.imdb                                       int64
# votes.filmCritics                                int64
# votes.russianFilmCritics                         int64
# votes.await                                      int64
# distributors.distributor                        object
# distributors.distributorRelease                 object
# premiere.world                     datetime64[ns, UTC]
# premiere.russia                    datetime64[ns, UTC]
# budget.value                                   float64
# budget.currency                                 object
# premiere.digital                                object
# premiere.dvd                                    object
# dtype: object

# %% [markdown]
# ### 2. Теперь обработаем пропуски

# %%
df_l.isna().sum()
# Out:
# movieLength                           1
# type                                  0
# name                                  0
# year                                  0
# genres                                0
# fees.world.value                    421
# fees.world.currency                 421
# fees.russia.value                  1276
# fees.russia.currency               1276
# fees.usa.value                     1167
# fees.usa.currency                  1167
# rating.kp                             0
# rating.imdb                           0
# rating.filmCritics                    0
# rating.russianFilmCritics             0
# rating.await                       3999
# votes.kp                              0
# votes.imdb                            0
# votes.filmCritics                     0
# votes.russianFilmCritics              0
# votes.await                           0
# distributors.distributor           1111
# distributors.distributorRelease    1512
# premiere.world                      145
# premiere.russia                     895
# budget.value                       1028
# budget.currency                    1028
# premiere.digital                   3992
# premiere.dvd                       3999
# dtype: int64

# %%
df_l[df_l['movieLength'].isnull()]
# Out:
#       movieLength   type     name  year   genres  fees.world.value  \
# 3481          NaN  movie  Не игра  2018  [драма]               NaN
#
#      fees.world.currency  fees.russia.value fees.russia.currency  \
# 3481                 NaN                NaN                  NaN
#
#       fees.usa.value  ... votes.russianFilmCritics  votes.await  \
# 3481             NaN  ...                        0            6
#
#       distributors.distributor  distributors.distributorRelease  \
# 3481                      None                             None
#
#                 premiere.world  premiere.russia  budget.value  \
# 3481 2018-02-16 00:00:00+00:00              NaT           NaN
#
#       budget.currency  premiere.digital  premiere.dvd
# 3481             None              None          None
#
# [1 rows x 29 columns]

# %% [markdown]
# В MovieLength один пропуск, это фильм "Не игра" -> удаляем строчку

# %%
df_l = df_l.drop(df_l[df_l['name'] == 'Не игра'].index)

# %% [markdown]
# Довольно много пропусков в колонках premiere.digital, rating.await, premiere.dvd: от 3993 до 3998 (всего 4000 наблюдений). В таком случае удалим их. Также удалим type, так как мы отбирали только фильмы.

# %%
df_l['type'].value_counts()
# Out:
# movie    3999
# Name: type, dtype: int64

# %%
df_l_dropped = df_l.drop(['premiere.digital', 'premiere.dvd', 'rating.await', 'type'], axis=1)

# %% [markdown]
# Валюту нужно привести к единому значению -> переводим евро в доллары

# %% [markdown]
# Для начала посмотрим, какая валюта вообще есть:

# %%
df_l_dropped['fees.world.currency'].value_counts()
# Out:
# $    3579
# Name: fees.world.currency, dtype: int64

# %%
df_l_dropped['fees.russia.currency'].value_counts()
# Out:
# $    2724
# Name: fees.russia.currency, dtype: int64

# %%
df_l_dropped['fees.usa.currency'].value_counts()
# Out:
# $    2833
# Name: fees.usa.currency, dtype: int64

# %% [markdown]
# То есть все сборы в $, здесь переводить ничего не надо. Посмотрим на бюджет:

# %%
df_l_dropped['budget.currency'].value_counts()
# Out:
# $      2665
# ₽       128
# €       102
# £        26
# FRF      11
# р.        9
# DKK       6
# CA$       6
# A$        4
# DEM       3
# NOK       3
# HK$       2
# SEK       1
# ₹         1
# CN¥       1
# ₴         1
# ATS       1
# FIM       1
# HUF       1
# Name: budget.currency, dtype: int64

# %% [markdown]
# Здесь довольно много разных валют, которые встречаются по паре раз. Удалим эти фильмы, а рубли, евро и фунты переведем в $ по текущему курсу:

# %%
df_l_dropped.loc[df_l_dropped['budget.currency'] == '€', 'budget.value'] *= 1.09
df_l_dropped.loc[df_l_dropped['budget.currency'] == '₽', 'budget.value'] *= 0.012
df_l_dropped.loc[df_l_dropped['budget.currency'] == '£', 'budget.value'] *= 1.26

# %%
df_l_dropped = df_l_dropped[
    (df_l_dropped['budget.currency'] == '€') |
    (df_l_dropped['budget.currency'] == '$') |
    (df_l_dropped['budget.currency'] == '₽') |
    (df_l_dropped['budget.currency'] == '£') |
    (df_l_dropped['budget.currency'].isnull())
]

# %%
df_l_dropped['budget.currency'].value_counts()
# Out:
# $    2665
# ₽     128
# €     102
# £      26
# Name: budget.currency, dtype: int64

# %%
df_l_dropped
# Out:
#       movieLength                    name  year  \
# 0           112.0                     1+1  2011
# 1           113.0             Джентльмены  2019
# 2           180.0       Волк с Уолл-стрит  2013
# 3           119.0       Гнев человеческий  2021
# 4           100.0                    Брат  1997
# ...           ...                     ...   ...
# 3995         95.0             Короли лета  2013
# 3996        116.0  Lil Peep: всё для всех  2019
# 3997         85.0                 Фантомы  2008
# 3998        103.0                   Выход  2019
# 3999        103.0        Мечты сбываются!  2013
#
#                                       genres  fees.world.value  \
# 0                [драма, комедия, биография]       426588510.0
# 1                [криминал, комедия, боевик]       115171795.0
# 2      [драма, криминал, биография, комедия]       392000694.0
# 3                          [боевик, триллер]       103966489.0
# 4                  [драма, криминал, боевик]         1362281.0
# ...                                      ...               ...
# 3995           [драма, комедия, приключения]         1501595.0
# 3996                [документальный, музыка]          748539.0
# 3997                                 [ужасы]        48555306.0
# 3998                       [боевик, комедия]        79410586.0
# 3999  [драма, комедия, мелодрама, биография]        10900434.0
#
#      fees.world.currency  fees.russia.value fees.russia.currency  \
# 0                      $          1725813.0                    $
# 1                      $         18003343.0                    $
# 2                      $         13796916.0                    $
# 3                      $         13318455.0                    $
# 4                      $                NaN                  NaN
# ...                  ...                ...                  ...
# 3995                   $             4252.0                    $
# 3996                   $           198254.0                    $
# 3997                   $          1811000.0                    $
# 3998                   $                NaN                  NaN
# 3999                   $                NaN                  NaN
#
#       fees.usa.value fees.usa.currency  ...  votes.imdb  votes.filmCritics  \
# 0         10198820.0                 $  ...      882411                130
# 1         36471795.0                 $  ...      361184                277
# 2        116900694.0                 $  ...     1465395                289
# 3         27466489.0                 $  ...      190690                256
# 4                NaN               NaN  ...       22847                  5
# ...              ...               ...  ...         ...                ...
# 3995       1315590.0                 $  ...       82970                123
# 3996        547207.0                 $  ...        3755                 21
# 3997      25928550.0                 $  ...       36172                 66
# 3998        470699.0                 $  ...        6843                  6
# 3999        101196.0                 $  ...       12831                 59
#
#       votes.russianFilmCritics  votes.await  distributors.distributor  \
# 0                           12           15              Каскад фильм
# 1                           22        13642                    Вольга
# 2                           31        43024                      West
# 3                           37        23492                    Вольга
# 4                            2            0       Кармен-Премьер, СТВ
# ...                        ...          ...                       ...
# 3995                         1          232          All Media, Арена
# 3996                         6          262               A-One Films
# 3997                         1            0    Двадцатый Век Фокс СНГ
# 3998                         0           37                      None
# 3999                         0          498                      None
#
#       distributors.distributorRelease            premiere.world  \
# 0                          Новый Диск 2011-09-23 00:00:00+00:00
# 1                                None 2019-12-03 00:00:00+00:00
# 2                          West Video 2013-12-09 00:00:00+00:00
# 3                                None 2021-04-22 00:00:00+00:00
# 4                          Союз-Видео 1997-05-17 00:00:00+00:00
# ...                               ...                       ...
# 3995                             None 2013-01-19 00:00:00+00:00
# 3996                             None 2019-01-10 00:00:00+00:00
# 3997           Двадцатый Век Фокс СНГ 2008-03-19 00:00:00+00:00
# 3998                             None 2019-07-31 00:00:00+00:00
# 3999                           Вольга 2013-09-09 00:00:00+00:00
#
#                premiere.russia  budget.value budget.currency
# 0    2012-04-26 00:00:00+00:00    10355000.0               €
# 1    2020-02-13 00:00:00+00:00    22000000.0               $
# 2    2014-02-06 00:00:00+00:00   100000000.0               $
# 3    2021-04-22 00:00:00+00:00    40000000.0               $
# 4    1997-12-12 00:00:00+00:00           NaN             NaN
# ...                        ...           ...             ...
# 3995 2013-10-03 00:00:00+00:00           NaN             NaN
# 3996 2019-11-21 00:00:00+00:00           NaN             NaN
# 3997 2008-04-03 00:00:00+00:00     8000000.0               $
# 3998                       NaT    11500000.0               $
# 3999                       NaT           NaN             NaN
#
# [3948 rows x 25 columns]

# %% [markdown]
# Теперь можем удалить стоблцы с валютой, так как у нас все значения в $ (с пропусками мы еще поработаем ниже):

# %%
df_l_dropped = df_l_dropped.drop(['fees.world.currency', 'fees.russia.currency', 'fees.usa.currency', 'budget.currency'], axis=1)
df_l_dropped
# Out:
#       movieLength                    name  year  \
# 0           112.0                     1+1  2011
# 1           113.0             Джентльмены  2019
# 2           180.0       Волк с Уолл-стрит  2013
# 3           119.0       Гнев человеческий  2021
# 4           100.0                    Брат  1997
# ...           ...                     ...   ...
# 3995         95.0             Короли лета  2013
# 3996        116.0  Lil Peep: всё для всех  2019
# 3997         85.0                 Фантомы  2008
# 3998        103.0                   Выход  2019
# 3999        103.0        Мечты сбываются!  2013
#
#                                       genres  fees.world.value  \
# 0                [драма, комедия, биография]       426588510.0
# 1                [криминал, комедия, боевик]       115171795.0
# 2      [драма, криминал, биография, комедия]       392000694.0
# 3                          [боевик, триллер]       103966489.0
# 4                  [драма, криминал, боевик]         1362281.0
# ...                                      ...               ...
# 3995           [драма, комедия, приключения]         1501595.0
# 3996                [документальный, музыка]          748539.0
# 3997                                 [ужасы]        48555306.0
# 3998                       [боевик, комедия]        79410586.0
# 3999  [драма, комедия, мелодрама, биография]        10900434.0
#
#       fees.russia.value  fees.usa.value  rating.kp  rating.imdb  \
# 0             1725813.0      10198820.0      8.805          8.5
# 1            18003343.0      36471795.0      8.548          7.8
# 2            13796916.0     116900694.0      7.973          8.2
# 3            13318455.0      27466489.0      7.590          7.1
# 4                   NaN             NaN      8.294          7.8
# ...                 ...             ...        ...          ...
# 3995             4252.0       1315590.0      6.769          7.1
# 3996           198254.0        547207.0      7.877          7.5
# 3997          1811000.0      25928550.0      6.194          5.2
# 3998                NaN        470699.0      7.354          7.0
# 3999                NaN        101196.0      7.343          6.8
#
#       rating.filmCritics  ...  votes.kp  votes.imdb  votes.filmCritics  \
# 0                    6.8  ...   1582052      882411                130
# 1                    6.5  ...   1404260      361184                277
# 2                    7.8  ...   1116549     1465395                289
# 3                    6.3  ...   1085059      190690                256
# 4                    7.6  ...   1058255       22847                  5
# ...                  ...  ...       ...         ...                ...
# 3995                 6.9  ...     23908       82970                123
# 3996                 7.4  ...     23904        3755                 21
# 3997                 3.5  ...     23882       36172                 66
# 3998                 6.0  ...     23881        6843                  6
# 3999                 5.5  ...     23881       12831                 59
#
#       votes.russianFilmCritics  votes.await  distributors.distributor  \
# 0                           12           15              Каскад фильм
# 1                           22        13642                    Вольга
# 2                           31        43024                      West
# 3                           37        23492                    Вольга
# 4                            2            0       Кармен-Премьер, СТВ
# ...                        ...          ...                       ...
# 3995                         1          232          All Media, Арена
# 3996                         6          262               A-One Films
# 3997                         1            0    Двадцатый Век Фокс СНГ
# 3998                         0           37                      None
# 3999                         0          498                      None
#
#      distributors.distributorRelease            premiere.world  \
# 0                         Новый Диск 2011-09-23 00:00:00+00:00
# 1                               None 2019-12-03 00:00:00+00:00
# 2                         West Video 2013-12-09 00:00:00+00:00
# 3                               None 2021-04-22 00:00:00+00:00
# 4                         Союз-Видео 1997-05-17 00:00:00+00:00
# ...                              ...                       ...
# 3995                            None 2013-01-19 00:00:00+00:00
# 3996                            None 2019-01-10 00:00:00+00:00
# 3997          Двадцатый Век Фокс СНГ 2008-03-19 00:00:00+00:00
# 3998                            None 2019-07-31 00:00:00+00:00
# 3999                          Вольга 2013-09-09 00:00:00+00:00
#
#                premiere.russia budget.value
# 0    2012-04-26 00:00:00+00:00   10355000.0
# 1    2020-02-13 00:00:00+00:00   22000000.0
# 2    2014-02-06 00:00:00+00:00  100000000.0
# 3    2021-04-22 00:00:00+00:00   40000000.0
# 4    1997-12-12 00:00:00+00:00          NaN
# ...                        ...          ...
# 3995 2013-10-03 00:00:00+00:00          NaN
# 3996 2019-11-21 00:00:00+00:00          NaN
# 3997 2008-04-03 00:00:00+00:00    8000000.0
# 3998                       NaT   11500000.0
# 3999                       NaT          NaN
#
# [3948 rows x 21 columns]

# %% [markdown]
# Заполним пропуски в столбцах со сборами и бюджетом средними значениями:

# %%
mfees_value_world = round(df_l_dropped['fees.world.value'].mean()) # Вычисление среднего значения столбца "fees.world.value" для отфильтрованных строк
mfees_value_world
# Out:
# 125275568

# %%
mfees_value_russia = round(df_l_dropped['fees.russia.value'].mean())
mfees_value_russia
# Out:
# 4345349

# %%
mfees_value_usa = round(df_l_dropped['fees.usa.value'].mean())
mfees_value_usa
# Out:
# 65760649

# %%
mbudget_value = round(df_l_dropped['budget.value'].mean())
mbudget_value
# Out:
# 45809569

# %%
# Замена пропущенных значений
df_l_dropped['fees.world.value'] = df_l_dropped['fees.world.value'].fillna(mfees_value_world)
df_l_dropped['fees.russia.value'] = df_l_dropped['fees.russia.value'].fillna(mfees_value_russia)
df_l_dropped['fees.usa.value'] = df_l_dropped['fees.usa.value'].fillna(mfees_value_usa)
df_l_dropped['budget.value'] = df_l_dropped['budget.value'].fillna(mbudget_value)

# %%
df_l_dropped.isna().sum()
# Out:
# movieLength                           0
# name                                  0
# year                                  0
# genres                                0
# fees.world.value                      0
# fees.russia.value                     0
# fees.usa.value                        0
# rating.kp                             0
# rating.imdb                           0
# rating.filmCritics                    0
# rating.russianFilmCritics             0
# votes.kp                              0
# votes.imdb                            0
# votes.filmCritics                     0
# votes.russianFilmCritics              0
# votes.await                           0
# distributors.distributor           1089
# distributors.distributorRelease    1495
# premiere.world                      145
# premiere.russia                     875
# budget.value                          0
# dtype: int64

# %%
df_l_dropped['budget.value'].head(10)
# Out:
# 0     10355000.0
# 1     22000000.0
# 2    100000000.0
# 3     40000000.0
# 4     45809569.0
# 5     18000000.0
# 6    237000000.0
# 7     25000000.0
# 8    160000000.0
# 9     60000000.0
# Name: budget.value, dtype: float64

# %% [markdown]
# Заполняем пропуски дистрибьютеров на "other", а столбец distributors.distributorRelease удалим, так как он не понадобиться для дальнейшего анализа.

# %%
df_l_dropped['distributors.distributor'] = df_l_dropped['distributors.distributor'].fillna('other')
df_l_dropped.drop('distributors.distributorRelease', axis=1, inplace=True)

# %% [markdown]
# Поработаем с колонками премьер (premiere.world и premiere.russia):

# %% [markdown]
# Проверим, как много фильмов с известной датой премьеры в России, но неизвестной в мировом прокате:

# %%
(df_l_dropped['premiere.russia'].isnull() & df_l_dropped['premiere.world'].notnull()).sum()
# Out:
# 853

# %% [markdown]
# Посмотрим, как много фильмов с известной датой премьеры в мировом прокате, но неизвестной в России:

# %%
(df_l_dropped['premiere.world'].isnull() & df_l_dropped['premiere.russia'].notnull()).sum()
# Out:
# 123

# %% [markdown]
# Наконец, проверим, как много фильмов с неизвестной датов премьеры в мире и в РФ:

# %%
(df_l_dropped['premiere.world'].isnull() & df_l_dropped['premiere.russia'].isnull()).sum()
# Out:
# 22

# %% [markdown]
# Таким образом, лучше всего будет заполнить пропуски в даты примьеры в РФ соотвествующими датами в мировом прокате, и наоброт. Остальные 22 фильма лучше удалить, потому что если их заполнить, к примеру, модой, то это может исказить дальнейший анализ.

# %%
df_l_dropped.loc[df_l_dropped['premiere.world'].isnull() & df_l_dropped['premiere.russia'].notnull(), 'premiere.world'] = df_l_dropped['premiere.russia']
df_l_dropped.loc[df_l_dropped['premiere.russia'].isnull() & df_l_dropped['premiere.world'].notnull(), 'premiere.russia'] = df_l_dropped['premiere.world']

# %%
df_l_dropped.dropna(subset=['premiere.world'], inplace=True)

# %%
df_l_dropped.isna().sum()
# Out:
# movieLength                  0
# name                         0
# year                         0
# genres                       0
# fees.world.value             0
# fees.russia.value            0
# fees.usa.value               0
# rating.kp                    0
# rating.imdb                  0
# rating.filmCritics           0
# rating.russianFilmCritics    0
# votes.kp                     0
# votes.imdb                   0
# votes.filmCritics            0
# votes.russianFilmCritics     0
# votes.await                  0
# distributors.distributor     0
# premiere.world               0
# premiere.russia              0
# budget.value                 0
# dtype: int64

# %% [markdown]
# Пропусков больше нет, летим дальше!

# %%
df_final = df_l_dropped

# %% [markdown]
# ### 3. Опишем данные

# %%
df_final
# Out:
#       movieLength                    name  year  \
# 0           112.0                     1+1  2011
# 1           113.0             Джентльмены  2019
# 2           180.0       Волк с Уолл-стрит  2013
# 3           119.0       Гнев человеческий  2021
# 4           100.0                    Брат  1997
# ...           ...                     ...   ...
# 3995         95.0             Короли лета  2013
# 3996        116.0  Lil Peep: всё для всех  2019
# 3997         85.0                 Фантомы  2008
# 3998        103.0                   Выход  2019
# 3999        103.0        Мечты сбываются!  2013
#
#                                       genres  fees.world.value  \
# 0                [драма, комедия, биография]       426588510.0
# 1                [криминал, комедия, боевик]       115171795.0
# 2      [драма, криминал, биография, комедия]       392000694.0
# 3                          [боевик, триллер]       103966489.0
# 4                  [драма, криминал, боевик]         1362281.0
# ...                                      ...               ...
# 3995           [драма, комедия, приключения]         1501595.0
# 3996                [документальный, музыка]          748539.0
# 3997                                 [ужасы]        48555306.0
# 3998                       [боевик, комедия]        79410586.0
# 3999  [драма, комедия, мелодрама, биография]        10900434.0
#
#       fees.russia.value  fees.usa.value  rating.kp  rating.imdb  \
# 0             1725813.0      10198820.0      8.805          8.5
# 1            18003343.0      36471795.0      8.548          7.8
# 2            13796916.0     116900694.0      7.973          8.2
# 3            13318455.0      27466489.0      7.590          7.1
# 4             4345349.0      65760649.0      8.294          7.8
# ...                 ...             ...        ...          ...
# 3995             4252.0       1315590.0      6.769          7.1
# 3996           198254.0        547207.0      7.877          7.5
# 3997          1811000.0      25928550.0      6.194          5.2
# 3998          4345349.0        470699.0      7.354          7.0
# 3999          4345349.0        101196.0      7.343          6.8
#
#       rating.filmCritics  rating.russianFilmCritics  votes.kp  votes.imdb  \
# 0                    6.8                   100.0000   1582052      882411
# 1                    6.5                    86.3636   1404260      361184
# 2                    7.8                    77.4194   1116549     1465395
# 3                    6.3                    72.9730   1085059      190690
# 4                    7.6                     0.0000   1058255       22847
# ...                  ...                        ...       ...         ...
# 3995                 6.9                     0.0000     23908       82970
# 3996                 7.4                    66.6667     23904        3755
# 3997                 3.5                     0.0000     23882       36172
# 3998                 6.0                     0.0000     23881        6843
# 3999                 5.5                     0.0000     23881       12831
#
#       votes.filmCritics  votes.russianFilmCritics  votes.await  \
# 0                   130                        12           15
# 1                   277                        22        13642
# 2                   289                        31        43024
# 3                   256                        37        23492
# 4                     5                         2            0
# ...                 ...                       ...          ...
# 3995                123                         1          232
# 3996                 21                         6          262
# 3997                 66                         1            0
# 3998                  6                         0           37
# 3999                 59                         0          498
#
#      distributors.distributor            premiere.world  \
# 0                Каскад фильм 2011-09-23 00:00:00+00:00
# 1                      Вольга 2019-12-03 00:00:00+00:00
# 2                        West 2013-12-09 00:00:00+00:00
# 3                      Вольга 2021-04-22 00:00:00+00:00
# 4         Кармен-Премьер, СТВ 1997-05-17 00:00:00+00:00
# ...                       ...                       ...
# 3995         All Media, Арена 2013-01-19 00:00:00+00:00
# 3996              A-One Films 2019-01-10 00:00:00+00:00
# 3997   Двадцатый Век Фокс СНГ 2008-03-19 00:00:00+00:00
# 3998                    other 2019-07-31 00:00:00+00:00
# 3999                    other 2013-09-09 00:00:00+00:00
#
#                premiere.russia  budget.value
# 0    2012-04-26 00:00:00+00:00    10355000.0
# 1    2020-02-13 00:00:00+00:00    22000000.0
# 2    2014-02-06 00:00:00+00:00   100000000.0
# 3    2021-04-22 00:00:00+00:00    40000000.0
# 4    1997-12-12 00:00:00+00:00    45809569.0
# ...                        ...           ...
# 3995 2013-10-03 00:00:00+00:00    45809569.0
# 3996 2019-11-21 00:00:00+00:00    45809569.0
# 3997 2008-04-03 00:00:00+00:00     8000000.0
# 3998 2019-07-31 00:00:00+00:00    11500000.0
# 3999 2013-09-09 00:00:00+00:00    45809569.0
#
# [3926 rows x 20 columns]

# %%
df_final.dtypes
# Out:
# movieLength                              float64
# name                                      object
# year                                       int64
# genres                                    object
# fees.world.value                         float64
# fees.russia.value                        float64
# fees.usa.value                           float64
# rating.kp                                float64
# rating.imdb                              float64
# rating.filmCritics                       float64
# rating.russianFilmCritics                float64
# votes.kp                                   int64
# votes.imdb                                 int64
# votes.filmCritics                          int64
# votes.russianFilmCritics                   int64
# votes.await                                int64
# distributors.distributor                  object
# premiere.world               datetime64[ns, UTC]
# premiere.russia              datetime64[ns, UTC]
# budget.value                             float64
# dtype: object

# %% [markdown]
# Опишем содержание каждой переменной:
# 1. movieLength — длина фильма в минутах
# 2. name — название фильма
# 3. year — год выпуска фильма
# 4. genres — жанры фильма
# 5. fees.world.value — сколько собрал фильм в мировом прокате
# 6. fees.russia.value — сколько собрал фильм в РФ
# 7. fees.usa.value — сколько собрал фильм в США
# 8. rating.kp — рейтинг фильма на Кинопоиске
# 9. rating.imdb — рейтинг фильма на IMDB
# 10. rating.filmCritics — рейтинг фильма у кинокритиков
# 11. rating.russianFilmCritics — рейтинг фильма у кинокритиков в РФ
# 12. votes.kp — количество голосов (оценок) на Кинопоиске
# 13. votes.imdb — количество голосов (оценок) на IMDB
# 14. votes.filmCritics — количество голосов кинокритиков
# 15. votes.russianFilmCritics — количество голосов кинокритиков из РФ
# 16. votes.await — количество пользователей, которые ожидали выхода фильма
# 17. distributors.distributor — дистрибьютор (или прокатчик) фильма в РФ
# 18. premiere.world — дата мировой премьеры
# 19. premiere.russia — дата премьеры в РФ
# 20. budget.value — бюджет фильма

# %% [markdown]
# ## Шаг 4. Визуализация (максимум 20 баллов)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df_final['rating.kp'])
plt.show()

# %%
plt.boxplot(df_final['movieLength'])
plt.show()

# %%
plt.hist(df_final['votes.kp'], bins=100, edgecolor='black', log=True)


plt.title('Распределение значений голосов')
plt.xlabel('Значения')
plt.ylabel('Частота')

plt.show()

# %%
plt.hist(df_final['votes.imdb'], bins=100, edgecolor='black', log=True)


plt.title('Распределение значений')
plt.xlabel('Значения')
plt.ylabel('Частота')

plt.show()

# %% [markdown]
# ## Шаг 6. Гипотезы (максимум 20 баллов)

# %% [markdown]
# Основная цель нашего проекта - научиться предсказывать кассовые сборы фильмов. На этапе визуализации, мы заметили, что на показатель сборов фильма/сериалы влияют такие метрики, как:
#
# - Период шоков
# - Дата выхода (выходной не выходной)
# - Длительность фильма
# - Бюджет фильма

# %% [markdown]
# Начнем тестирование гипотез, которые сформулируем точнее далее. Сейчас необходимо добавить переменные, которые перевидут категориальные признаки в бинарный вид:
# Дата выхода: выходной - 1, не выходной - 0. Под выходными подразумеваем праздники и сб, вс.
# Период шоков:

# %%
# Посмотрим на года, по которым у нас есть данные
unique_values = df_final['premiere.world'].unique()
years = [value.year for value in unique_values]
unique_years = sorted(set(years))
print(unique_years)
# Out:
# [1921, 1925, 1931, 1936, 1938, 1939, 1940, 1941, 1942, 1946, 1947, 1950, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %% [markdown]
# У нас есть данные с 1921 года, однако логичнее ориентироваться на шоки, в период после 2000 года, ввиду ряда причин:
# 1. Активное развитие киноиндустрии
# 2. Инфляция (фильмы в 20 веке собирали меньше, по причинам экономической ситуации в мире - другие средние показатели по инфляции, потреблению, общему благосостоянию населения и тд)

# %%
# Добавили колонку "Year" и "Total fees", для удобства
df_final['Year'] = df_final['premiere.world'].apply(lambda x: x.year)
df_final['Total fees'] = df_final[['fees.world.value', 'fees.russia.value', 'fees.usa.value']].sum(axis=1)
df_final
# Out:
#       movieLength                    name  year  \
# 0           112.0                     1+1  2011
# 1           113.0             Джентльмены  2019
# 2           180.0       Волк с Уолл-стрит  2013
# 3           119.0       Гнев человеческий  2021
# 4           100.0                    Брат  1997
# ...           ...                     ...   ...
# 3995         95.0             Короли лета  2013
# 3996        116.0  Lil Peep: всё для всех  2019
# 3997         85.0                 Фантомы  2008
# 3998        103.0                   Выход  2019
# 3999        103.0        Мечты сбываются!  2013
#
#                                       genres  fees.world.value  \
# 0                [драма, комедия, биография]       426588510.0
# 1                [криминал, комедия, боевик]       115171795.0
# 2      [драма, криминал, биография, комедия]       392000694.0
# 3                          [боевик, триллер]       103966489.0
# 4                  [драма, криминал, боевик]         1362281.0
# ...                                      ...               ...
# 3995           [драма, комедия, приключения]         1501595.0
# 3996                [документальный, музыка]          748539.0
# 3997                                 [ужасы]        48555306.0
# 3998                       [боевик, комедия]        79410586.0
# 3999  [драма, комедия, мелодрама, биография]        10900434.0
#
#       fees.russia.value  fees.usa.value  rating.kp  rating.imdb  \
# 0             1725813.0      10198820.0      8.805          8.5
# 1            18003343.0      36471795.0      8.548          7.8
# 2            13796916.0     116900694.0      7.973          8.2
# 3            13318455.0      27466489.0      7.590          7.1
# 4             4345349.0      65760649.0      8.294          7.8
# ...                 ...             ...        ...          ...
# 3995             4252.0       1315590.0      6.769          7.1
# 3996           198254.0        547207.0      7.877          7.5
# 3997          1811000.0      25928550.0      6.194          5.2
# 3998          4345349.0        470699.0      7.354          7.0
# 3999          4345349.0        101196.0      7.343          6.8
#
#       rating.filmCritics  ...  votes.imdb  votes.filmCritics  \
# 0                    6.8  ...      882411                130
# 1                    6.5  ...      361184                277
# 2                    7.8  ...     1465395                289
# 3                    6.3  ...      190690                256
# 4                    7.6  ...       22847                  5
# ...                  ...  ...         ...                ...
# 3995                 6.9  ...       82970                123
# 3996                 7.4  ...        3755                 21
# 3997                 3.5  ...       36172                 66
# 3998                 6.0  ...        6843                  6
# 3999                 5.5  ...       12831                 59
#
#       votes.russianFilmCritics  votes.await  distributors.distributor  \
# 0                           12           15              Каскад фильм
# 1                           22        13642                    Вольга
# 2                           31        43024                      West
# 3                           37        23492                    Вольга
# 4                            2            0       Кармен-Премьер, СТВ
# ...                        ...          ...                       ...
# 3995                         1          232          All Media, Арена
# 3996                         6          262               A-One Films
# 3997                         1            0    Двадцатый Век Фокс СНГ
# 3998                         0           37                     other
# 3999                         0          498                     other
#
#                 premiere.world           premiere.russia budget.value  Year  \
# 0    2011-09-23 00:00:00+00:00 2012-04-26 00:00:00+00:00   10355000.0  2011
# 1    2019-12-03 00:00:00+00:00 2020-02-13 00:00:00+00:00   22000000.0  2019
# 2    2013-12-09 00:00:00+00:00 2014-02-06 00:00:00+00:00  100000000.0  2013
# 3    2021-04-22 00:00:00+00:00 2021-04-22 00:00:00+00:00   40000000.0  2021
# 4    1997-05-17 00:00:00+00:00 1997-12-12 00:00:00+00:00   45809569.0  1997
# ...                        ...                       ...          ...   ...
# 3995 2013-01-19 00:00:00+00:00 2013-10-03 00:00:00+00:00   45809569.0  2013
# 3996 2019-01-10 00:00:00+00:00 2019-11-21 00:00:00+00:00   45809569.0  2019
# 3997 2008-03-19 00:00:00+00:00 2008-04-03 00:00:00+00:00    8000000.0  2008
# 3998 2019-07-31 00:00:00+00:00 2019-07-31 00:00:00+00:00   11500000.0  2019
# 3999 2013-09-09 00:00:00+00:00 2013-09-09 00:00:00+00:00   45809569.0  2013
#
#        Total fees
# 0     438513143.0
# 1     169646933.0
# 2     522698304.0
# 3     144751433.0
# 4      71468279.0
# ...           ...
# 3995    2821437.0
# 3996    1494000.0
# 3997   76294856.0
# 3998   84226634.0
# 3999   15346979.0
#
# [3926 rows x 22 columns]

# %%
df_filtered = df_final[df_final['Year'] <= 2000]

fig = plt.figure(figsize=(10, 6), dpi=100)
ax = fig.add_subplot(111)

plt.scatter(df_filtered['Year'], df_filtered['Total fees'])
plt.xlabel('Year')
plt.ylabel('Total fees')
plt.title('Scatter Plot of Total fees vs. Year (Before 2000)')

plt.xticks(df_filtered['Year'], rotation=60)
plt.show()

# %%
df_filtered = df_final[df_final['Year'] >= 1987]

fig = plt.figure(figsize=(10, 6), dpi=100)
ax = fig.add_subplot(111)

plt.scatter(df_filtered['Year'], df_filtered['Total fees'])
plt.xlabel('Year')
plt.ylabel('Total fees')
plt.title('Scatter Plot of Total fees vs. Year (Before 2000)')

plt.xticks(df_filtered['Year'], rotation=60)
plt.show()

# %% [markdown]
# ## Шаг 7. Машинное обучение (максимум 20 баллов)
# Скорее всего, в ваших данных есть какая-то переменная, которую есть смысл попробовать предсказать. Подробно объясните, что именно вы собираетесь предсказывать и зачем. Какую задачу вы решаете? Какую метрику вы будете использовать для того, чтобы измерить качество вашей модели?
#
# Аккуратно разбейте выборку на обучающую и тестовую, сделайте всю необходимую предобработку данных и обучите несколько моделей. Подберите для них все необходимые гиперпараметры. Проанализируйте получившиеся результаты и сделайте выводы.

# %%
df_final
# Out:
#       movieLength                    name  year  \
# 0           112.0                     1+1  2011
# 1           113.0             Джентльмены  2019
# 2           180.0       Волк с Уолл-стрит  2013
# 3           119.0       Гнев человеческий  2021
# 4           100.0                    Брат  1997
# ...           ...                     ...   ...
# 3995         95.0             Короли лета  2013
# 3996        116.0  Lil Peep: всё для всех  2019
# 3997         85.0                 Фантомы  2008
# 3998        103.0                   Выход  2019
# 3999        103.0        Мечты сбываются!  2013
#
#                                       genres  fees.world.value  \
# 0                [драма, комедия, биография]       426588510.0
# 1                [криминал, комедия, боевик]       115171795.0
# 2      [драма, криминал, биография, комедия]       392000694.0
# 3                          [боевик, триллер]       103966489.0
# 4                  [драма, криминал, боевик]         1362281.0
# ...                                      ...               ...
# 3995           [драма, комедия, приключения]         1501595.0
# 3996                [документальный, музыка]          748539.0
# 3997                                 [ужасы]        48555306.0
# 3998                       [боевик, комедия]        79410586.0
# 3999  [драма, комедия, мелодрама, биография]        10900434.0
#
#       fees.russia.value  fees.usa.value  rating.kp  rating.imdb  \
# 0             1725813.0      10198820.0      8.805          8.5
# 1            18003343.0      36471795.0      8.548          7.8
# 2            13796916.0     116900694.0      7.973          8.2
# 3            13318455.0      27466489.0      7.590          7.1
# 4             4345349.0      65760649.0      8.294          7.8
# ...                 ...             ...        ...          ...
# 3995             4252.0       1315590.0      6.769          7.1
# 3996           198254.0        547207.0      7.877          7.5
# 3997          1811000.0      25928550.0      6.194          5.2
# 3998          4345349.0        470699.0      7.354          7.0
# 3999          4345349.0        101196.0      7.343          6.8
#
#       rating.filmCritics  rating.russianFilmCritics  votes.kp  votes.imdb  \
# 0                    6.8                   100.0000   1582052      882411
# 1                    6.5                    86.3636   1404260      361184
# 2                    7.8                    77.4194   1116549     1465395
# 3                    6.3                    72.9730   1085059      190690
# 4                    7.6                     0.0000   1058255       22847
# ...                  ...                        ...       ...         ...
# 3995                 6.9                     0.0000     23908       82970
# 3996                 7.4                    66.6667     23904        3755
# 3997                 3.5                     0.0000     23882       36172
# 3998                 6.0                     0.0000     23881        6843
# 3999                 5.5                     0.0000     23881       12831
#
#       votes.filmCritics  votes.russianFilmCritics  votes.await  \
# 0                   130                        12           15
# 1                   277                        22        13642
# 2                   289                        31        43024
# 3                   256                        37        23492
# 4                     5                         2            0
# ...                 ...                       ...          ...
# 3995                123                         1          232
# 3996                 21                         6          262
# 3997                 66                         1            0
# 3998                  6                         0           37
# 3999                 59                         0          498
#
#      distributors.distributor            premiere.world  \
# 0                Каскад фильм 2011-09-23 00:00:00+00:00
# 1                      Вольга 2019-12-03 00:00:00+00:00
# 2                        West 2013-12-09 00:00:00+00:00
# 3                      Вольга 2021-04-22 00:00:00+00:00
# 4         Кармен-Премьер, СТВ 1997-05-17 00:00:00+00:00
# ...                       ...                       ...
# 3995         All Media, Арена 2013-01-19 00:00:00+00:00
# 3996              A-One Films 2019-01-10 00:00:00+00:00
# 3997   Двадцатый Век Фокс СНГ 2008-03-19 00:00:00+00:00
# 3998                    other 2019-07-31 00:00:00+00:00
# 3999                    other 2013-09-09 00:00:00+00:00
#
#                premiere.russia  budget.value
# 0    2012-04-26 00:00:00+00:00    10355000.0
# 1    2020-02-13 00:00:00+00:00    22000000.0
# 2    2014-02-06 00:00:00+00:00   100000000.0
# 3    2021-04-22 00:00:00+00:00    40000000.0
# 4    1997-12-12 00:00:00+00:00    45809569.0
# ...                        ...           ...
# 3995 2013-10-03 00:00:00+00:00    45809569.0
# 3996 2019-11-21 00:00:00+00:00    45809569.0
# 3997 2008-04-03 00:00:00+00:00     8000000.0
# 3998 2019-07-31 00:00:00+00:00    11500000.0
# 3999 2013-09-09 00:00:00+00:00    45809569.0
#
# [3926 rows x 20 columns]
