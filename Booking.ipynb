# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as pd
import time

# %%
pip install fake_useragent
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from fake_useragent import UserAgent
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_4; en-US) AppleWebKit/534.1 (KHTML, like Gecko) Chrome/6.0.414.0 Safari/534.1'

# %%
all_links = []
numbers = [0, 25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350, 375, 400, 425, 450, 475, 500, 525, 550, 575, 600, 625, 650, 675, 700, 725, 750, 775, 800, 825, 850, 875, 900, 925, 950, 975, 1000]
for i in numbers:
    url1 = 'https://www.booking.com/searchresults.ru.html?label=gog235jc-1DCAEoggI46AdIM1gDaE2IAQGYASG4ARjIAQ3YAQPoAQGIAgGoAgS4AoPHg6MGwAIB0gIkZWRkOWQ1ZjQtZTM5My00MzQ5LWE0ZTQtYWNiODM2NGJlZTA42AIE4AIB&sid=961e8a339039e2ee9365cb56193ce90a&aid=397594&ss=Испания&ssne=Турция&ssne_untouched=Турция&lang=ru&src=index&dest_id=197&dest_type=country&ac_position=0&ac_click_type=b&ac_langcode=ru&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=17625f82fbdf0566&ac_meta=GhAxNzYyNWY4MmZiZGYwNTY2IAAoATICcnU6DtC40YHQv9Cw0L3QuNGPQABKAFAA&checkin=2023-07-05&checkout=2023-07-21&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&nflt=ht_beach%3D1%3Bht_id%3D201&offset=' + str(i)
    response1 = requests.get(url, headers={'User-Agent': UserAgent().chrome})
    html1 = response.content
    soup1 = BeautifulSoup(html1,'html.parser')
    links1 = soup.find_all('a', {'class' : "e13098a59f"})
    for link in links1:
        mom = link.get('href')
        all_links.append(mom)
all_links
# Out:
# ['https://www.booking.com/hotel/es/apartment-sun-of-andalucia-sitio-de-calahonda.ru.html?label=gog235jc-1DCAEoggI46AdIM1gDaE2IAQGYASG4ARjIAQ3YAQPoAQGIAgGoAgS4AoPHg6MGwAIB0gIkZWRkOWQ1ZjQtZTM5My00MzQ5LWE0ZTQtYWNiODM2NGJlZTA42AIE4AIB&sid=961e8a339039e2ee9365cb56193ce90a&aid=397594&ucfs=1&arphpl=1&checkin=2023-07-05&checkout=2023-07-21&dest_id=197&dest_type=country&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=ht_beach%3D1%3Bht_id%3D201&srpvid=d36b5fb272f000b6&srepoch=1684071399&all_sr_blocks=305745801_329774446_2_0_0&highlighted_blocks=305745801_329774446_2_0_0&matching_block_id=305745801_329774446_2_0_0&sr_pri_blocks=305745801_329774446_2_0_0__182144&from_sustainable_property_sr=1&from=searchresults#hotelTmpl',
# ...

# %%
len(all_links)
# Out:
# 1025

# %%
test_link = all_links[0]
test_link
# Out:
# 'https://www.booking.com/hotel/es/apartment-sun-of-andalucia-sitio-de-calahonda.ru.html?label=gog235jc-1DCAEoggI46AdIM1gDaE2IAQGYASG4ARjIAQ3YAQPoAQGIAgGoAgS4AoPHg6MGwAIB0gIkZWRkOWQ1ZjQtZTM5My00MzQ5LWE0ZTQtYWNiODM2NGJlZTA42AIE4AIB&sid=961e8a339039e2ee9365cb56193ce90a&aid=397594&ucfs=1&arphpl=1&checkin=2023-07-05&checkout=2023-07-21&dest_id=197&dest_type=country&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=ht_beach%3D1%3Bht_id%3D201&srpvid=d36b5fb272f000b6&srepoch=1684071399&all_sr_blocks=305745801_329774446_2_0_0&highlighted_blocks=305745801_329774446_2_0_0&matching_block_id=305745801_329774446_2_0_0&sr_pri_blocks=305745801_329774446_2_0_0__182144&from_sustainable_property_sr=1&from=searchresults#hotelTmpl'

# %%
<h2 class="d2fee87262 pp-header__title">Apartment Sun of Andalucia</h2>

# %%
page_link1 = test_link
res = requests.get(page_link1)
html1 = res.content
soup1 = BeautifulSoup(html1,'html.parser')
soup1
# Out:
# <!DOCTYPE html>
#
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# https://careers.booking.com/
# -->
# <!-- wdot-802 -->
# <script nonce="liUqQB31bDZoaFv" type="text/javascript">
# document.addEventListener('DOMContentLoaded', function () {
# /**
# * provides the current user's cookie consent
# * in order to use it:
# * 1. inline privacy/cookieConsent.js in the page you need to use it.
# * please note that this library relies on window.PCM.isCountryNeedCookieBanner to be initialised
# * before using (calling getValue function) it
# * 2. in your js file:
# *
# * var privacyCookieConsent = B.require('privacyCookieConsent');
# * var consent = privacyCookieConsent.getValue();
# */
# B.define('privacyCookieConsent', function () {
# var consentGroupIsAllowed = {
# analytical: 'C0002%3A1',
# marketing: 'C0004%3A1'
# };
# var optanonConsentCookieName = 'OptanonConsent';
# ...

# %%
name1 = soup1.find_all('h2', {'class' : "d2fee87262 pp-header__title"})
print(name1[0].text)
# Out:
# Apartment Sun of Andalucia

# %%
place1 = soup1.find_all('span', {'class' : "hp_address_subtitle js-hp_address_subtitle jq_tooltip"})
print(place1[0].text)
# Out:
# Calle Mar de Calahonda, 29649 Ситио-де-Калаонда, Испания
